# %%
import pandas as pd
import numpy as np
import os
from pandas import Series, DataFrame, Panel
from datetime import datetime

# %%
import plotly.plotly as py
import cufflinks as cf

# %%
from matplotlib import pyplot

# %%
filename = './data/iranian_tweets_csv_hashed.csv'

# %%
iran= pd.read_csv(filename, dtype = {
    "tweetid": str,
    "userid": str,
    "user_display_name": str,
    "user_screen_name": str,
    "user_reported_location": str,
    "user_profile_description": str,
    "user_profile_url": str,
    "follower_count": str,
    "following_count": str,
    "account_creation_date": str,
    "account_language": str,
    "tweet_text": str,
    "tweet_time": str,
    "tweet_client_name": str,
    "in_reply_to_tweetid": str,
    "in_reply_to_userid": str,
    "quoted_tweet_tweetid": str,
    "is_retweet": bool,
    "retweet_userid": str,
    "retweet_tweetid": str,
    "latitude": str,
    "longitude": str,
    "quote_count": str,
    "reply_count": str,
    "like_count": str,
    "retweet_count": str,
    "hashtags": str,
    "urls": str,
    "user_mentions": str,
    "poll_choices": str,
})

# %%
print(len(iran))
# Out:
# 1122936

# %%
iran.columns
# Out:
# Index(['tweetid', 'userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language', 'tweet_text', 'tweet_time',
#        'tweet_client_name', 'in_reply_to_tweetid', 'in_reply_to_userid',
#        'quoted_tweet_tweetid', 'is_retweet', 'retweet_userid',
#        'retweet_tweetid', 'latitude', 'longitude', 'quote_count',
#        'reply_count', 'like_count', 'retweet_count', 'hashtags', 'urls',
#        'user_mentions', 'poll_choices'],
#       dtype='object')

# %%
#russia['tweet_time']

# %%
iran['tweet_record_time'] = pd.to_datetime(iran['tweet_time'], format ='%Y-%m-%d %H:%M')

# %%
#russia['tweet_record_time']

# %%
time = []

# %%
for i in iran['tweet_record_time']:
    time.append(i.time())
    #print(i.time())

# %%
iran['time'] = time

# %%
hour =[]

# %%
for i in iran['time']:
    hour.append(i.hour)
    #print(i.time())

# %%
iran['hour'] = hour

# %%
iran.head()
# Out:
#               tweetid     userid user_display_name user_screen_name  \
# 0  533622371429543936  299148448        Maria Luis      marialuis91
# 1  527205814906654721  299148448        Maria Luis      marialuis91
# 2  545166827350134784  299148448        Maria Luis      marialuis91
# 3  538045437316321280  299148448        Maria Luis      marialuis91
# 4  530053681668841472  299148448        Maria Luis      marialuis91
#
#   user_reported_location                           user_profile_description  \
# 0         Nantes, France  journaliste indépendante/un vrai journaliste e...
# 1         Nantes, France  journaliste indépendante/un vrai journaliste e...
# 2         Nantes, France  journaliste indépendante/un vrai journaliste e...
# 3         Nantes, France  journaliste indépendante/un vrai journaliste e...
# 4         Nantes, France  journaliste indépendante/un vrai journaliste e...
#
#   user_profile_url follower_count following_count account_creation_date ...   \
# 0              NaN           8012            1450            2011-05-15 ...
# 1              NaN           8012            1450            2011-05-15 ...
# 2              NaN           8012            1450            2011-05-15 ...
# 3              NaN           8012            1450            2011-05-15 ...
# 4              NaN           8012            1450            2011-05-15 ...
#
#   reply_count like_count retweet_count hashtags  \
# 0         0.0        0.0           0.0      NaN
# 1         0.0        0.0           0.0      NaN
# 2         0.0        0.0           0.0      NaN
# 3         0.0        0.0           0.0      NaN
# 4         0.0        1.0           2.0      NaN
#
#                                                 urls        user_mentions  \
# 0  [http://fr.awdnews.com/divertissements/5757-ce...          [574356455]
# 1  [http://www.awdnews.com/top-news/10080-an-inqu...          [438542436]
# 2  [http://www.awdnews.com/political/10404-cia-pr...  [823905, 256625456]
# 3  [http://fr.awdnews.com/divertissements/5796-to...          [919513172]
# 4  [http://fr.awdnews.com/soci%C3%A9t%C3%A9/5723-...           [83864876]
#
#   poll_choices   tweet_record_time      time hour
# 0          NaN 2014-11-15 14:07:00  14:07:00   14
# 1          NaN 2014-10-28 21:10:00  21:10:00   21
# 2          NaN 2014-12-17 10:41:00  10:41:00   10
# 3          NaN 2014-11-27 19:03:00  19:03:00   19
# 4          NaN 2014-11-05 17:47:00  17:47:00   17
#
# [5 rows x 34 columns]

# %%
#cf.set_config_file(offline=False, world_readable=True, theme='ggplot')

#russia.iplot(x='time',kind='scatter')

# %%
iran['hour'].hist(bins = 30)

# %%
#russia['hour'].plot()
#pyplot.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
pd.crosstab(index=iran['user_reported_location'],   columns="count").sort_values(by=['count'])
# Out:
# col_0                                                count
# user_reported_location
# Asia                                                     1
# US                                                       1
# Portland, OR                                             3
# Iran, Tehran                                             3
# Ohio, USA                                                3
# Ohio                                                     3
# الخليج العربي دولة الكويت                                4
# North Holland, The Netherlands                           5
# Sasdat Abad، TEHRAN، IRAN                                7
# Bahrain                                                  7
# Sacramento, CA                                           7
# Al Madinah Al Munawwarah                                 8
# Amman                                                    9
# برمودا                                                   9
# کره زمین                                                11
# Oregon, USA                                             13
# Arab World                                              14
# Texas, USA                                              15
# TeHrAn                                                  16
# Nederland                                               17
# Califor                                                 17
# شلمچه ، فکه ، مجنون                                     18
# Munich, Bavaria                                         20
# ایران ، تهران ، خونمون                                  20
# الأردن                                                  22
# Toronto, Ontario                                        26
# بهشت                                                    27
# jordan                                                  29
# پاستور                                                  30
# المنطقة الشرقية - اقليم المشرق في شبه الجزيرة ا...      31
# ...                                                    ...
# Libya                                                 4170
# California, USA                                       4179
# Houston, TX                                           4349
# کلوت شهداد                                            4476
# Iran - Tehran                                         4649
# Tehran, Iran                                          5439
# تهران                                                 5589
# istanbul                                              6095
# Hashemite Kingdom of Jordan                           6218
# Afghanistan                                           6475
# insanın lisanı...                                     7330
# France                                                7559
# Islamic Republic of Iran                              7671
# Türkiye                                               8144
# شمال                                                  8784
# هر جا که این قلب ببره                                 9562
# España                                                9835
# New York, USA                                         9923
# Syrian Arab Republic                                 12867
# فلسطين                                               12881
# Riyadh                                               13327
# United States                                        16286
# Paris, France                                        20090
# Germany                                              27144
# United Kingdom                                       28320
# Moscow                                               34010
# Kingdom of Saudi Arabia                              59591
# İstanbul, Türkiye 🇹🇷                                 68808
# Brazil                                              101956
# Nantes, France                                      265448
#
# [200 rows x 1 columns]
