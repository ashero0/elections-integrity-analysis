# %%
import pandas as pd
import numpy as np
import os
from pandas import Series, DataFrame, Panel
from datetime import datetime

# %%
import plotly.plotly as py
import cufflinks as cf

# %%
from matplotlib import pyplot

# %%
filename = './data/russia_201901_1_tweets_csv_hashed.csv'

# %%
russia = pd.read_csv(filename, dtype = {
    "tweetid": str,
    "userid": str,
    "user_display_name": str,
    "user_screen_name": str,
    "user_reported_location": str,
    "user_profile_description": str,
    "user_profile_url": str,
    "follower_count": str,
    "following_count": str,
    "account_creation_date": str,
    "account_language": str,
    "tweet_text": str,
    "tweet_time": str,
    "tweet_client_name": str,
    "in_reply_to_tweetid": str,
    "in_reply_to_userid": str,
    "quoted_tweet_tweetid": str,
    "is_retweet": bool,
    "retweet_userid": str,
    "retweet_tweetid": str,
    "latitude": str,
    "longitude": str,
    "quote_count": str,
    "reply_count": str,
    "like_count": str,
    "retweet_count": str,
    "hashtags": str,
    "urls": str,
    "user_mentions": str,
    "poll_choices": str,
})

# %%
print(len(russia))
# Out:
# 765246

# %%
russia.columns
# Out:
# Index(['tweetid', 'userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language', 'tweet_text', 'tweet_time',
#        'tweet_client_name', 'in_reply_to_tweetid', 'in_reply_to_userid',
#        'quoted_tweet_tweetid', 'is_retweet', 'retweet_userid',
#        'retweet_tweetid', 'latitude', 'longitude', 'quote_count',
#        'reply_count', 'like_count', 'retweet_count', 'hashtags', 'urls',
#        'user_mentions', 'poll_choices'],
#       dtype='object')

# %%
#russia['tweet_time']

# %%
russia['tweet_record_time'] = pd.to_datetime(russia['tweet_time'], format ='%Y-%m-%d %H:%M')

# %%
#russia['tweet_record_time']

# %%
time = []

# %%
for i in russia['tweet_record_time']:
    time.append(i.time())
    #print(i.time())

# %%
russia['time'] = time

# %%
hour =[]

# %%
for i in russia['time']:
    hour.append(i.hour)
    #print(i.time())

# %%
russia['hour'] = hour

# %%
russia.head()
# Out:
#               tweetid                                        userid  \
# 0  507097592116035584  TfAIZXAy2WKyIaMRGRo5Bc7TvYn5jid4HDIhZjHGuL0=
# 1  634855237140873217  aX+o4MEU0jsv3nWf6rkY9XdnJo+lUKxMZ3dB4rKPeIg=
# 2  679020335602122752                                    2980186012
# 3  709190244881408000                                    2980186012
# 4  630988235649347584                                    2980186012
#
#                               user_display_name  \
# 0  TfAIZXAy2WKyIaMRGRo5Bc7TvYn5jid4HDIhZjHGuL0=
# 1  aX+o4MEU0jsv3nWf6rkY9XdnJo+lUKxMZ3dB4rKPeIg=
# 2                               Infidel II 🕋💣🕋💩
# 3                               Infidel II 🕋💣🕋💩
# 4                               Infidel II 🕋💣🕋💩
#
#                                user_screen_name  \
# 0  TfAIZXAy2WKyIaMRGRo5Bc7TvYn5jid4HDIhZjHGuL0=
# 1  aX+o4MEU0jsv3nWf6rkY9XdnJo+lUKxMZ3dB4rKPeIg=
# 2                               CathyTo47590555
# 3                               CathyTo47590555
# 4                               CathyTo47590555
#
#            user_reported_location  \
# 0                   New York, USA
# 1                   New York, USA
# 2  USA  #IslamIsTheProbem #WakeUp
# 3  USA  #IslamIsTheProbem #WakeUp
# 4  USA  #IslamIsTheProbem #WakeUp
#
#                             user_profile_description user_profile_url  \
# 0                       Just another day on the job.              NaN
# 1  3 years  ... Hardcore twitter fanatic #My stor...              NaN
# 2  I believe that OUR COUNTRY needs to BAN ISLAM ...              NaN
# 3  I believe that OUR COUNTRY needs to BAN ISLAM ...              NaN
# 4  I believe that OUR COUNTRY needs to BAN ISLAM ...              NaN
#
#   follower_count following_count account_creation_date ...  reply_count  \
# 0            101             137            2013-08-26 ...          0.0
# 1             56              94            2015-03-12 ...          0.0
# 2           8685            1451            2015-01-15 ...          0.0
# 3           8685            1451            2015-01-15 ...          0.0
# 4           8685            1451            2015-01-15 ...          0.0
#
#   like_count retweet_count             hashtags                      urls  \
# 0        0.0           0.0                  NaN                       NaN
# 1        0.0           0.0                   []                        []
# 2        0.0           0.0  [IslamIsTheProblem]                        []
# 3        0.0           0.0                   []   [http://bit.ly/1pFckqD]
# 4        0.0           0.0                   []  [http://huff.to/1MlMpgm]
#
#                    user_mentions poll_choices   tweet_record_time      time  \
# 0                            NaN          NaN 2014-09-03 09:27:00  09:27:00
# 1                             []          NaN 2015-08-21 22:30:00  22:30:00
# 2                  [PigeonToday]          NaN 2015-12-21 19:27:00  19:27:00
# 3  [AnnCoulter, realDonaldTrump]          NaN 2016-03-14 01:31:00  01:31:00
# 4                  [HuffPostPol]          NaN 2015-08-11 06:24:00  06:24:00
#
#   hour
# 0    9
# 1   22
# 2   19
# 3    1
# 4    6
#
# [5 rows x 33 columns]

# %%
#cf.set_config_file(offline=False, world_readable=True, theme='ggplot')

#russia.iplot(x='time',kind='scatter')

# %%
russia['hour'].hist(bins = 30)

# %%
#russia['hour'].plot()
#pyplot.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
pd.crosstab(index=russia['user_reported_location'],   columns="count").sort_values(by=['count'])
# Out:
# col_0                            count
# user_reported_location
# Cleveland                            1
# Chester                              3
# Lichfield\t                          4
# Austria                              5
# Istanbul via Liverpool               7
# US                                   9
# Stockholm                           19
# NY                                  38
# new york                            41
# Tampa, FL                           47
# St. Petersburg, Russia.             51
# New Jersey, USA                    118
# Lithuania                          182
# Lyon, France                       203
# USA/England/Spain/Itay/Germany     240
# Miami, FL                          246
# Newcastle                          389
# Jersey City, NJ                    413
# United states                      473
# Zimbabwe                           531
# Wichita, Kansas                    558
# New York, NY                       595
# Sankt-Petersburg                   634
# New York                          1273
# France                            2306
# Paris, France                     2373
# Russia, Kaliningrad               2918
# Syria                             5828
# World 🌍 *BFF Of SamTheInfidel     5829
# USA                              10252
# United States 🌎🇺🇸                18202
# New York, USA                    29885
# Earth                            57530
# United States                   303025
# USA  #IslamIsTheProbem #WakeUp  313065
