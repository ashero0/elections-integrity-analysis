# %% [markdown]
# # Analyze user account geo location and visualize it on world map

# %%
import nltk

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\lizda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\lizda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\lizda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Load IRA users

# %%
filename = './data/ira_users_csv_hashed.csv'

# %%
users = pd.read_csv(filename, dtype = {
    "tweetid": str,
    "userid": str,
    "user_display_name": str,
    "user_screen_name": str,
    "user_reported_location": str,
    "user_profile_description": str,
    "user_profile_url": str,
    "follower_count": str,
    "following_count": str,
    "account_creation_date": str,
    "account_language": str,
    "tweet_text": str,
    "tweet_time": str,
    "tweet_client_name": str,
    "in_reply_to_tweetid": str,
    "in_reply_to_userid": str,
    "quoted_tweet_tweetid": str,
    "is_retweet": bool,
    "retweet_userid": str,
    "retweet_tweetid": str,
    "latitude": str,
    "longitude": str,
    "quote_count": str,
    "reply_count": str,
    "like_count": str,
    "retweet_count": str,
    "hashtags": str,
    "urls": str,
    "user_mentions": str,
    "poll_choices": str,
})

# %%
# Number of user accounts
print(len(users))
# Out:
# 3608

# %%
# user account attributes
users.columns
# Out:
# Index(['userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language'],
#       dtype='object')

# %% [markdown]
# ## Raw user location count

# %%
pd.crosstab(index=users['user_reported_location'],   columns="count").sort_values(by=['count'], ascending=False)
# Out:
# col_0                         count
# user_reported_location
# USA                             670
# Москва                          206
# United States                   116
# Atlanta                          73
# Санкт-Петербург                  66
# US                               65
# Питер                            62
# Россия                           55
# Moscow                           48
# New York, USA                    42
# МSK                              38
# Новосибирск                      38
# Москва, Россия                   37
# Новгород                         36
# NY                               33
# Омск                             31
# Germany                          30
# LA                               29
# Boston                           24
# New York                         19
# New York, NY                     18
# Санкт-Петербург, Россия          18
# Чебоксары                        17
# Russia                           16
# Atlanta, GA                      16
# Los Angeles                      16
# سوريا                            16
# Syria                            15
# Chicago                          12
# Казань                           12
# ...                             ...
# Rostock, Deutschland              1
# San Diego, United States          1
# San Diego                         1
# Salt Lake City                    1
# Salem, Massachusetts              1
# Saint-Peterburg                   1
# Saint-P.                          1
# Saint-P                           1
# Saint Petersburg                  1
# Saarbrücken, Deutschland          1
# SPb♥○•°•☆                         1
# Russian Empire                    1
# Russia, Moscow                    1
# Rostov-na-Donu, Russia            1
# Riverside                         1
# Penza                             1
# Rhode island                      1
# Rhode Island                      1
# Republic of Chechnya, Russia      1
# Redwood City, California          1
# Rancho Rinconada, CA, USA         1
# Raleigh, North Carolina           1
# Queens, NY                        1
# Poland                            1
# Pittsburgh, US                    1
# Pittsburgh, PA                    1
# Pittsburgh                        1
# Philly                            1
# Philadelhia                       1
# ✴Новгород✴                        1
#
# [631 rows x 1 columns]

# %%
users['user_reported_location'] = users['user_reported_location'].fillna(' ')

# %%
users['user_reported_location'] = users['user_reported_location'].replace(" ", "")

# %% [markdown]
# ## Try to translate

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
len(users['user_reported_location'])
# Out:
# 3608

# %%
# users['en_locaton'] = [translator.translate(x, dest='en').text for x in users['user_reported_location']]

# %%
count = 0
translated_loc = []
for x in users['user_reported_location']: 
    print(count)
    print("Try : ", x)
    translation = translator.translate(x, dest='en')
    print("become:",translation.text,"end")
    count+=1
    translated_loc.append(translation.text)
    if(count > 20):
        translator = Translator()
        count = 0
# Out:
# 0
# Try :  USA
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-102-d66888924c9c> in <module>
#       4     print(count)
#       5     print("Try : ", x)
# ----> 6     translation = translator.translate(x, dest='en')
#       7     print("become:",translation.text,"end")
#       8     count+=1
#
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\site-packages\googletrans\client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
#      80
# ---> 81         data = utils.format_json(r.text)
#      82         return data
#      83
#
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\site-packages\googletrans\utils.py in format_json(original)
#      60         converted = json.loads(original)
#      61     except ValueError:
# ---> 62         converted = legacy_format_json(original)
#      63
#      64     return converted
#
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\site-packages\googletrans\utils.py in legacy_format_json(original)
#      52             text = text[:p] + states[j][1] + text[nxt:]
#      53
# ---> 54     converted = json.loads(text)
#      55     return converted
#      56
#
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
users['en_loc'] = translated_loc

# %%
users = users.loc[users['en_loc'].str.contains('USA'),'en_loc'].replace('USA', 'United State')

# %%
users.head()
# Out:
# 0     United State
# 6     United State
# 7     United State
# 13    United State
# 29    United State
# Name: en_loc, dtype: object

# %%
pd.crosstab(index=users['en_loc'],   columns="count").sort_values(by=['count'], ascending=False)
# Out:
# col_0                       count
# en_loc
#                               672
# USA                           670
# Moscow                        259
# United States                 116
# Russia                         76
# Atlanta                        73
# St. Petersburg                 71
# US                             65
# Peter                          65
# Moscow, Russia                 48
# New York, USA                  42
# Novosibirsk                    39
# CSO                            38
# Novgorod                       37
# Omsk                           34
# Germany                        33
# NEW                            33
# Syria                          31
# THE                            30
# Boston                         24
# SPB                            20
# New York                       19
# Saint-Petersburg, Russia       18
# The Angels                     18
# New York, NY                   18
# Cheboksary                     17
# Atlanta, GA                    16
# Chicago                        13
# Yekaterinburg                  12
# Kazan                          12
# ...                           ...
# Kaluga, Russia                  1
# Kaluga                          1
# Lugansk                         1
# Lyon                            1
# Montgomery                      1
# Lyubertsy                       1
# Mohnton, PA                     1
# Missouri, USA                   1
# Minsk                           1
# Milwaukee, WI                   1
# Millville village, OH, USA      1
# Milford, Ohio                   1
# Milan, Lombardy                 1
# Michigan                        1
# Miami, USA                      1
# Mexico                          1
# Mesa                            1
# Meniscot                        1
# Memphis                         1
# Meadows                         1
# Mariupol                        1
# Manila                          1
# Manama, Bahrain                 1
# Man                             1
# Magdeburg, Germany              1
# Magadan                         1
# Macon, GA                       1
# MSK SAO                         1
# MOSCOW                          1
# ✴Новгород✴                      1
#
# [570 rows x 1 columns]

# %%
# import copy
# from googletrans import Translator

# translatedList = []
# for index, row in df.iterrows():
#     # REINITIALIZE THE API
#     translator = Translator()
#     newrow = copy.deepcopy(row)
#     try:
#         # translate the 'text' column
#         translated = translator.translate(row['text'], dest='en')
#         newrow['translated'] = translated.text
#     except Exception as e:
#         print(str(e))
#         continue
#     translatedList.append(newrow)

# %% [markdown]
# ### GEO CODE

# %%
# import geograpy3

# text_input = "Perfect just Perfect! It's a perfect storm for Nairobi"
# more_places = geograpy3.get_place_context(text = text_input)
# print(more_places.cities)

# %%
cities = []
countries = []

# %%
from geotext import GeoText
for x in users['user_reported_location']: 
    print("Try : ", x)
    places = GeoText(x)
    cities.append(str(places.cities))
    countries.append(str(places.countries))
    print("GET",places.cities, " and country ", places.countries)
# Out:
# Try :  USA
# GET []  and country  []
# Try :  Раша
# GET []  and country  []
# Try :  Чеченская республика, Россия
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Camden, NJ
# GET ['Camden']  and country  []
# Try :  Dallas
# GET ['Dallas']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Madison
# GET ['Madison']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Мурманск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  Alaska
# GET []  and country  []
# Try :  Chester, PA
# GET ['Chester']  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  Pennsylvania
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  München, Bayern
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  France
# GET []  and country  ['France']
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  United Kingdom
# GET []  and country  ['United Kingdom']
# Try :  Rostock, Deutschland
# GET ['Rostock']  and country  []
# Try :  US
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  омск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Mohnton, PA
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :  America
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Грозный
# GET []  and country  []
# Try :  Russia
# GET []  and country  ['Russia']
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  New York, NY
# GET ['New York']  and country  []
# Try :  Nashville
# GET ['Nashville']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Newport
# GET ['Newport']  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  ATL
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Estados Unidos
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Utah
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  новгород
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Ульяновск
# GET []  and country  []
# Try :  Arizona
# GET []  and country  []
# Try :  Казань
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Смоленск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Köln, Deutschland
# GET ['Köln']  and country  []
# Try :
# GET []  and country  []
# Try :  Orlando
# GET ['Orlando']  and country  []
# Try :
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :   Bloomfield Hills, Michigan
# GET ['Michigan']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  Серпухов
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  St.Petersburg
# GET ['Petersburg']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Артем
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Moscow, Russia
# GET ['Moscow']  and country  ['Russia']
# Try :  Moscow, Russia
# GET ['Moscow']  and country  ['Russia']
# Try :  temple hills, md
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Boston
# GET ['Boston']  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Boston
# GET ['Boston']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  Ostin
# GET []  and country  []
# Try :  Berlin, Deutschland
# GET ['Berlin']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Вологда
# GET []  and country  []
# Try :  Nashville
# GET ['Nashville']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Seattle, WA
# GET ['Seattle']  and country  []
# Try :
# GET []  and country  []
# Try :  New York, NY
# GET ['New York']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  San Diego, CA
# GET ['San Diego']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Чебоксары
# GET []  and country  []
# Try :  New York, NY
# GET ['New York']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Old Bridge, New Jersey
# GET ['Old Bridge']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  СПБ
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  Louisville
# GET ['Louisville']  and country  []
# Try :  Орел
# GET []  and country  []
# Try :  Baldwinsville, New York
# GET ['New York']  and country  []
# Try :  California
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Тверь
# GET []  and country  []
# Try :  Тверь
# GET []  and country  []
# Try :  دمشق
# GET []  and country  []
# Try :  Frankfurt am Main, Deutschland
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :  Нижний Новгород
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Estados Unidos
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Pennsylvania
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  London
# GET ['London']  and country  []
# Try :  МSK
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Miami, USA
# GET ['Miami']  and country  []
# Try :  Иркутск
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  New York, NY
# GET ['New York']  and country  []
# Try :  Волгоград
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Miami, FL
# GET ['Miami']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  سورية
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Baltimore, MD
# GET ['Baltimore']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  حمص
# GET []  and country  []
# Try :  Minnesota
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Уфа
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :  حلب
# GET []  and country  []
# Try :  Ростов-На-Дону
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-петербург
# GET []  and country  []
# Try :  usa
# GET []  and country  []
# Try :  St.Petersburg
# GET ['Petersburg']  and country  []
# Try :  Los Angeles
# GET ['Los Angeles']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Russia
# GET []  and country  ['Russia']
# Try :  Philadelhia
# GET []  and country  []
# Try :  Baltimore, MD
# GET ['Baltimore']  and country  []
# Try :  Oklahoma
# GET ['Oklahoma']  and country  []
# Try :  СПБ
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Ватноград
# GET []  and country  []
# Try :  Черемухи
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Pittsburgh, PA
# GET ['Pittsburgh']  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  France
# GET []  and country  ['France']
# Try :
# GET []  and country  []
# Try :  North Port, FL
# GET ['North Port']  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  Калининград
# GET []  and country  []
# Try :  spb
# GET []  and country  []
# Try :  Псков
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  SPB
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Coventry
# GET ['Coventry']  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Kansas, USA
# GET ['Kansas']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Erfurt, Deutschland
# GET ['Erfurt']  and country  []
# Try :  Вильнюс - Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  California, USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Бутово
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Hessen, Deutschland
# GET []  and country  []
# Try :  Российская Федерация
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Raleigh, North Carolina
# GET ['Raleigh']  and country  []
# Try :  Сочи
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Columbus, Ohio
# GET ['Columbus']  and country  []
# Try :
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Москва
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Miami
# GET ['Miami']  and country  []
# Try :  Deutschland
# GET []  and country  []
# Try :  لبنان
# GET []  and country  []
# Try :  OH
# GET []  and country  []
# Try :  Wisconsin, USA
# GET []  and country  []
# Try :  hood
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  Perm, Russia
# GET ['Perm']  and country  ['Russia']
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Спб
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Jackson
# GET ['Jackson']  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  SPB
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Третий Рим
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Чебоксары
# GET []  and country  []
# Try :  Казань
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  Manhattan, NY
# GET ['Manhattan']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  New York, NY
# GET ['New York']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Moscow, Russia
# GET ['Moscow']  and country  ['Russia']
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Lebanon
# GET []  and country  ['Lebanon']
# Try :  Los Gatos, California
# GET ['Los Gatos']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  piter
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  Saint Petersburg
# GET ['Saint Petersburg']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  Калининград
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Russia
# GET []  and country  ['Russia']
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  France
# GET []  and country  ['France']
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Texas, USA
# GET ['Texas']  and country  []
# Try :  Austin
# GET ['Austin']  and country  []
# Try :
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Сочи
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Düsseldorf, Deutschland
# GET []  and country  []
# Try :  Saarbrücken, Deutschland
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  Memphis, TN
# GET ['Memphis']  and country  []
# Try :  Омск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  Amerika
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  SF
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  New-York
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Донецк
# GET []  and country  []
# Try :  Syria
# GET []  and country  ['Syria']
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Washington
# GET ['Washington']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :  Kansas
# GET ['Kansas']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  СПБ
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Manchester
# GET ['Manchester']  and country  []
# Try :  Выборг
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  LA
# GET []  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  St. Petersburg
# GET ['Petersburg']  and country  []
# Try :
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  New Haven
# GET ['New Haven']  and country  []
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  London
# GET ['London']  and country  []
# Try :  Ferguson, MO
# GET ['Ferguson']  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  America
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  Black America
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  Dresden, Sachsen
# GET ['Dresden']  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Newark, NJ
# GET ['Newark']  and country  []
# Try :  Washington, D.C.
# GET ['Washington']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  омск
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Запорожье
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Липецк
# GET []  and country  []
# Try :  Dallas
# GET ['Dallas']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  ATL
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Washington, D.C.
# GET ['Washington']  and country  []
# Try :  Velikiy Novgorod, Russia
# GET ['Velikiy Novgorod']  and country  ['Russia']
# Try :  USA
# GET []  and country  []
# Try :  MN
# GET []  and country  []
# Try :  دمشق
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Саратов )))
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Омск, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  UK
# GET []  and country  []
# Try :  Phoenix
# GET ['Phoenix']  and country  []
# Try :
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Казань
# GET []  and country  []
# Try :  Minneapolis, MN
# GET ['Minneapolis']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Philadelphia, PA
# GET ['Philadelphia']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Oliva Pizza & Pasta // Amman
# GET ['Amman']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  NY City
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Мурманск
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Italy
# GET []  and country  ['Italy']
# Try :  Russia
# GET []  and country  ['Russia']
# Try :
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Chelyabinsk, Russia
# GET ['Chelyabinsk']  and country  ['Russia']
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Моска
# GET []  and country  []
# Try :  Волгоград
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  spb
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Texas
# GET ['Texas']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Estados Unidos
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Nebraska, USA
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :  San-Francisco
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  US
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  New York
# GET ['New York']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :  Grove City, Ohio
# GET ['Grove City']  and country  []
# Try :
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Arizona, USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  San Diego, United States
# GET ['San Diego']  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Нижний Новгород
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Новгород - СПб
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Київ
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  Мечта
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Хабаровск
# GET []  and country  []
# Try :  РФ
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :  saint p.
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Pittsburgh
# GET ['Pittsburgh']  and country  []
# Try :
# GET []  and country  []
# Try :  питер
# GET []  and country  []
# Try :  Tallahassee
# GET ['Tallahassee']  and country  []
# Try :  New Jersey, USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Работа))
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :  Houston, TX
# GET ['Houston']  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  دمشق
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  America
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :
# GET []  and country  []
# Try :  Rancho Rinconada, CA, USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :  ростов-я-тону
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  Colorado
# GET ['Colorado']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Нижний Новгород
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Arizona
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Ташла
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Выборг
# GET []  and country  []
# Try :  Beirut
# GET ['Beirut']  and country  []
# Try :  Hollywood
# GET ['Hollywood']  and country  []
# Try :
# GET []  and country  []
# Try :  New York, NY
# GET ['New York']  and country  []
# Try :
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  Phoenix
# GET ['Phoenix']  and country  []
# Try :  Philadelphia
# GET ['Philadelphia']  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :  ID
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Milwaukee, WI
# GET ['Milwaukee']  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Guanica zona urbana, PR, USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  питер
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  London, UK
# GET ['London']  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  Italy
# GET []  and country  ['Italy']
# Try :  Мурманск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Los-Angeles
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  ул. Ленина
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Russia
# GET []  and country  ['Russia']
# Try :
# GET []  and country  []
# Try :  Islamic States of America
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  New York
# GET ['New York']  and country  []
# Try :  nyc
# GET []  and country  []
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :  Киров
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Коломна
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Italia
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Eldorado at Santa Fe, NM, USA
# GET ['Santa Fe']  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Greensboro
# GET ['Greensboro']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Казань
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Macon, GA
# GET ['Macon']  and country  []
# Try :  Philadelphia
# GET ['Philadelphia']  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  Washington
# GET ['Washington']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  спб
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  Иваново
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  Montgomery
# GET ['Montgomery']  and country  []
# Try :
# GET []  and country  []
# Try :  Тула
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :
# GET []  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Russia, Moscow
# GET ['Moscow']  and country  ['Russia']
# Try :  Damascus
# GET ['Damascus']  and country  []
# Try :  Moscow, Russia
# GET ['Moscow']  and country  ['Russia']
# Try :  Петрозаводск
# GET []  and country  []
# Try :  Philadelphia
# GET ['Philadelphia']  and country  []
# Try :
# GET []  and country  []
# Try :  Екатеринбург
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Hamburg, Deutschland
# GET ['Hamburg']  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  cleveland / ohio
# GET []  and country  []
# Try :  Texas, USA
# GET ['Texas']  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  ✴Новгород✴
# GET []  and country  []
# Try :  СПб
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  Мінск
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Сочи
# GET []  and country  []
# Try :  Волгоград, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Nashville
# GET ['Nashville']  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Chicago, IL
# GET ['Chicago']  and country  []
# Try :  Хабаровск, Россия
# GET []  and country  []
# Try :  Brooklyn
# GET ['Brooklyn']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  омск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  МСК
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :  	Austin
# GET ['Austin']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Minnesota
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  دمشق
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Екатеринбург
# GET []  and country  []
# Try :  Georgia, USA
# GET []  and country  ['Georgia']
# Try :  Россия
# GET []  and country  []
# Try :  Liberty City
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  sin city
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Washington
# GET ['Washington']  and country  []
# Try :  Одесса
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  brooklyn
# GET []  and country  []
# Try :  Redwood City, California
# GET ['Redwood City']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Я везде
# GET []  and country  []
# Try :  Greece
# GET []  and country  ['Greece']
# Try :
# GET []  and country  []
# Try :  Тверь
# GET []  and country  []
# Try :  دمشق
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Cosmopolitanism
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :  Manama, Bahrain
# GET ['Manama']  and country  ['Bahrain']
# Try :  екб
# GET []  and country  []
# Try :  Chicago, IL
# GET ['Chicago']  and country  []
# Try :  Philadelphia
# GET ['Philadelphia']  and country  []
# Try :  Coventry
# GET ['Coventry']  and country  []
# Try :  Витебск
# GET []  and country  []
# Try :  Набережные Челны, Россия
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Kuwait
# GET []  and country  ['Kuwait']
# Try :  Новосибирск
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  belgorod
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Тува
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Казань
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Nizhniy Novgorod, Russia
# GET ['Nizhniy Novgorod']  and country  ['Russia']
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Boston
# GET ['Boston']  and country  []
# Try :  Newhustle
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Новосибирск
# GET []  and country  []
# Try :  moscow city
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  Волгоград
# GET []  and country  []
# Try :  россия
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  Киев
# GET []  and country  []
# Try :  Johnson City, New York
# GET ['Johnson City', 'New York']  and country  []
# Try :  Baltimore, MD
# GET ['Baltimore']  and country  []
# Try :  Brussel, België
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Ярославль
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Стамбул
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Houston, TX
# GET ['Houston']  and country  []
# Try :  Houston
# GET ['Houston']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Сочи
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :  СПб
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  New York, NY
# GET ['New York']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Philadelphia
# GET ['Philadelphia']  and country  []
# Try :  Bremen, Deutschland
# GET ['Bremen']  and country  []
# Try :  US
# GET []  and country  []
# Try :  Saint Petersburg, Russia
# GET ['Saint Petersburg']  and country  ['Russia']
# Try :  Москва
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Москва, Россия
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  North Carolina
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Beirut
# GET ['Beirut']  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :  Los Angeles
# GET ['Los Angeles']  and country  []
# Try :  New Hampshire
# GET []  and country  []
# Try :  Мурманск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Ярославль
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Пушкин
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  Москва
# GET []  and country  []
# Try :  ARIZONA
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Челябинск
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  SPB
# GET []  and country  []
# Try :  New Orleans, LA
# GET ['New Orleans']  and country  []
# Try :
# GET []  and country  []
# Try :  St.Petersburg
# GET ['Petersburg']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  msk
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :
# GET []  and country  []
# Try :  Arizona
# GET []  and country  []
# Try :  Arizona
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Downtown, Atlanta
# GET ['Atlanta']  and country  []
# Try :  San-Francisco
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Stonewall, TX
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Краснодар
# GET []  and country  []
# Try :  عمان
# GET []  and country  []
# Try :  Newcastle
# GET ['Newcastle']  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Самара
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  MN
# GET []  and country  []
# Try :  Новосибирск, Россия
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Newcastle
# GET ['Newcastle']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Казань
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  saint P.
# GET []  and country  []
# Try :  Ростов
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Мечтовиль
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Kiel, Schleswig-Holstein
# GET ['Kiel']  and country  []
# Try :  سورية
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Los Angeles, CA
# GET ['Los Angeles']  and country  []
# Try :  Louisiana
# GET []  and country  []
# Try :  New York City
# GET ['New York']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Los Angeles
# GET ['Los Angeles']  and country  []
# Try :  Сочи
# GET []  and country  []
# Try :  MSK SAO
# GET []  and country  []
# Try :  Syria
# GET []  and country  ['Syria']
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  msk
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  МСК
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Baltimore, MD
# GET ['Baltimore']  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  уфа
# GET []  and country  []
# Try :  Washington D.C
# GET ['Washington']  and country  []
# Try :  Wonderland
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Syria
# GET []  and country  ['Syria']
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :   Santa Barbara, California
# GET ['Santa Barbara']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Boston
# GET ['Boston']  and country  []
# Try :  Zarqa, Jordan
# GET ['Zarqa']  and country  ['Jordan']
# Try :  Russia
# GET []  and country  ['Russia']
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  USA
# GET []  and country  []
# Try :  novgorod
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Oklahoma City
# GET ['Oklahoma City']  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Питер
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  Los Alamos
# GET []  and country  []
# Try :  حماة
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Rhode Island
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  SPb
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  москва
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  LA
# GET []  and country  []
# Try :  Люберцы
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Man
# GET ['Man']  and country  []
# Try :  Волгоград
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Memphis, TN
# GET ['Memphis']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  SPB
# GET []  and country  []
# Try :  Phoenix
# GET ['Phoenix']  and country  []
# Try :  Kansas, USA
# GET ['Kansas']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  South Carolina, USA
# GET []  and country  []
# Try :  Серпухов
# GET []  and country  []
# ...
# GET []  and country  []
# Try :  London
# GET ['London']  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Miami, FL
# GET ['Miami']  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Louisville
# GET ['Louisville']  and country  []
# Try :
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Волгоград
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Philly
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  اللاذقية
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  London
# GET ['London']  and country  []
# Try :  Moscow-City
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  New York
# GET ['New York']  and country  []
# Try :
# GET []  and country  []
# Try :  Калининград
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Houston
# GET ['Houston']  and country  []
# Try :  Красноярск
# GET []  and country  []
# Try :  Amman
# GET ['Amman']  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Омск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Fowler, California
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Penza
# GET ['Penza']  and country  []
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :  Ростов
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Севастополь
# GET []  and country  []
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :  Jacksonville
# GET ['Jacksonville']  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  МСКВА
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Чебоксары
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  Чита
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  City of San Antonio, TX
# GET ['San Antonio']  and country  []
# Try :  Лос-Питербургос
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Los Angeles, CA
# GET ['Los Angeles']  and country  []
# Try :
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :  Atlanta, Georgia
# GET ['Atlanta']  and country  ['Georgia']
# Try :  Москва - столица
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Россия
# GET []  and country  []
# Try :  Чебоксары
# GET []  and country  []
# Try :  Владик ДВФУ
# GET []  and country  []
# Try :  KN
# GET []  and country  []
# Try :  City of Phoenix, Arizona
# GET ['Phoenix']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Курск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  us
# GET []  and country  []
# Try :  Ростов
# GET []  and country  []
# Try :  Тверь
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  Boston
# GET ['Boston']  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  МSK
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  Симферополь
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Washington D.C
# GET ['Washington']  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :
# GET []  and country  []
# Try :  Саратов
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :
# GET []  and country  []
# Try :  Тула, Россия
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  arkansas
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Ростов-на-Дону
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-Петербург, Россия
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Потсдам
# GET []  and country  []
# Try :  Winchester, Virginia
# GET ['Winchester', 'Virginia']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Сочи
# GET []  and country  []
# Try :  Frankfurt am Main, Hessen
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  MSK
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Симферополь
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :  الأردن
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  New-York
# GET []  and country  []
# Try :  Love Town
# GET []  and country  []
# Try :  AL
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  РФ
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  Nashville
# GET ['Nashville']  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :  ny
# GET []  and country  []
# Try :  СПБ
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :
# GET []  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  Тверь
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :  Washington, DC
# GET ['Washington']  and country  []
# Try :  Los Angeles
# GET ['Los Angeles']  and country  []
# Try :
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  NY
# GET []  and country  []
# Try :  Los Angeles, CA
# GET ['Los Angeles']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  New York City
# GET ['New York']  and country  []
# Try :  Россия Санкт-Петербург
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  AMERICA
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  НН
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Moscow, Russia
# GET ['Moscow']  and country  ['Russia']
# Try :  Нижний Новгород
# GET []  and country  []
# Try :  San-Francisco
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Miami
# GET ['Miami']  and country  []
# Try :  Новосибирск
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Омск
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Chicago, IL
# GET ['Chicago']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Russia
# GET []  and country  ['Russia']
# Try :  Houston, TX
# GET ['Houston']  and country  []
# Try :  Florida, USA
# GET ['Florida']  and country  []
# Try :  دمشق
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  garage
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Кемерово
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  НН
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  France
# GET []  and country  ['France']
# Try :  italia
# GET []  and country  []
# Try :  Москва, Россия
# GET []  and country  []
# Try :  Salt Lake City
# GET ['Salt Lake']  and country  []
# Try :  Venice, California
# GET ['Venice']  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Adler
# GET ['Adler']  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Киев
# GET []  and country  []
# Try :  Питер
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Тула
# GET []  and country  []
# Try :  МСК
# GET []  and country  []
# Try :  Moscow
# GET ['Moscow']  and country  []
# Try :  СПб
# GET []  and country  []
# Try :  France
# GET []  and country  ['France']
# Try :  United States
# GET []  and country  ['United States']
# Try :  USA
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  مصر
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Kansas, USA
# GET ['Kansas']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Los Angeles
# GET ['Los Angeles']  and country  []
# Try :  Пермь
# GET []  and country  []
# Try :  Нижний Новгород
# GET []  and country  []
# Try :  Ярославль
# GET []  and country  []
# Try :  Syria
# GET []  and country  ['Syria']
# Try :  Los Angeles
# GET ['Los Angeles']  and country  []
# Try :
# GET []  and country  []
# Try :  NH
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Omsk, Russia
# GET ['Omsk']  and country  ['Russia']
# Try :  Томск
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :  Atlanta, GA
# GET ['Atlanta']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  NH
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Germany
# GET []  and country  ['Germany']
# Try :  Syria
# GET []  and country  ['Syria']
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Coventry
# GET ['Coventry']  and country  []
# Try :  Россия, Казань
# GET []  and country  []
# Try :  New York, USA
# GET ['New York']  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  US
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Atlanta
# GET ['Atlanta']  and country  []
# Try :  Вологда
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  US
# GET []  and country  []
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :
# GET []  and country  []
# Try :  New Jersey
# GET []  and country  []
# Try :   Kansas
# GET ['Kansas']  and country  []
# Try :
# GET []  and country  []
# Try :  Russia
# GET []  and country  ['Russia']
# Try :  Россия
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :  Boston
# GET ['Boston']  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  LA
# GET []  and country  []
# Try :  Новгород
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Kansas City, MO
# GET ['Kansas City']  and country  []
# Try :  Berlin, Deutschland
# GET ['Berlin']  and country  []
# Try :  Чебоксары
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Волгоград
# GET []  and country  []
# Try :  Baton Rouge, LA
# GET ['Baton Rouge']  and country  []
# Try :  USA
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  سوريا
# GET []  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  Philadelphia
# GET ['Philadelphia']  and country  []
# Try :
# GET []  and country  []
# Try :  United States
# GET []  and country  ['United States']
# Try :
# GET []  and country  []
# Try :  Texas, USA
# GET ['Texas']  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Москва
# GET []  and country  []
# Try :  London, England
# GET ['London']  and country  []
# Try :  New York
# GET ['New York']  and country  []
# Try :  Egypt
# GET []  and country  ['Egypt']
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :  Нягань
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  USA
# GET []  and country  []
# Try :  Chicago
# GET ['Chicago']  and country  []
# Try :  Stavropol, Russia
# GET []  and country  ['Russia']
# Try :  USA
# GET []  and country  []
# Try :  Ленинград
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  New York, NY
# GET ['New York']  and country  []
# Try :  Санкт-Петербург
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  МSK
# GET []  and country  []
# Try :
# GET []  and country  []
# Try :  US
# GET []  and country  []

# %%
from geotext import GeoText
for x in users['user_reported_location']: 
    print("Try : ", x)
    if(x):
        places = geograpy3.get_place_context(text = x)
        print("GET",places.cities)
# Out:
# Try :  USA
# GET []
# Try :  Раша
# GET []
# Try :  Чеченская республика, Россия
# GET []
# Try :  US
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Camden, NJ
# GET ['Camden']
# Try :  Dallas
# GET []
# Try :
# Try :
# Try :  Madison
# GET ['Madison']
# Try :  USA
# GET []
# Try :  Мурманск
# GET []
# Try :
# Try :
# Try :
# Try :  Germany
# GET []
# Try :  Alaska
# GET []
# Try :  Chester, PA
# GET ['Chester']
# Try :  Питер
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  سوريا
# GET []
# Try :  Pennsylvania
# GET []
# Try :
# Try :  US
# GET []
# Try :
# Try :  USA
# GET []
# Try :  München, Bayern
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :  France
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Новгород
# GET []
# Try :
# Try :  United Kingdom
# GET []
# Try :  Rostock, Deutschland
# GET ['Rostock']
# Try :  US
# GET []
# Try :  US
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  омск
# GET []
# Try :
# Try :
# Try :
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  Mohnton, PA
# GET ['Mohnton']
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  America
# GET ['America']
# Try :
# Try :
# Try :  Грозный
# GET []
# Try :  Russia
# GET ['Russia']
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  New York, NY
# GET ['New York']
# Try :  Nashville
# GET ['Nashville']
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  سوريا
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  Newport
# GET ['Newport']
# Try :  Moscow
# GET ['Moscow']
# Try :  ATL
# GET []
# Try :
# Try :
# Try :  Estados Unidos
# GET []
# Try :  United States
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Utah
# GET []
# Try :  Москва
# GET []
# Try :  новгород
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Ульяновск
# GET []
# Try :  Arizona
# GET []
# Try :  Казань
# GET []
# Try :  Москва
# GET []
# Try :  Питер
# GET []
# Try :  US
# GET []
# Try :  Смоленск
# GET []
# Try :  USA
# GET []
# Try :  Köln, Deutschland
# GET []
# Try :
# Try :  Orlando
# GET ['Orlando']
# Try :
# Try :  سوريا
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :   Bloomfield Hills, Michigan
# GET ['Bloomfield', 'Hills']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Серпухов
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  St.Petersburg
# GET []
# Try :
# Try :
# Try :  Артем
# GET []
# Try :  NY
# GET []
# Try :
# Try :  US
# GET []
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Moscow, Russia
# GET ['Moscow', 'Russia']
# Try :  Moscow, Russia
# GET ['Moscow', 'Russia']
# Try :  temple hills, md
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  Питер
# GET []
# Try :  Москва, Россия
# GET []
# Try :  USA
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  USA
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Ostin
# GET []
# Try :  Berlin, Deutschland
# GET ['Berlin']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  NY
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Вологда
# GET []
# Try :  Nashville
# GET ['Nashville']
# Try :  Москва
# GET []
# Try :  Seattle, WA
# GET ['Seattle']
# Try :
# Try :  New York, NY
# GET ['New York']
# Try :  USA
# GET []
# Try :  San Diego, CA
# GET ['San Diego']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Чебоксары
# GET []
# Try :  New York, NY
# GET ['New York']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Old Bridge, New Jersey
# GET ['Bridge']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  СПБ
# GET []
# Try :  МSK
# GET []
# Try :  Louisville
# GET ['Louisville']
# Try :  Орел
# GET []
# Try :  Baldwinsville, New York
# GET ['New York', 'Baldwinsville']
# Try :  California
# GET ['California']
# Try :  LA
# GET []
# Try :
# Try :  Тверь
# GET []
# Try :  Тверь
# GET []
# Try :  دمشق
# GET []
# Try :  Frankfurt am Main, Deutschland
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  Нижний Новгород
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Estados Unidos
# GET []
# Try :  USA
# GET []
# Try :  Pennsylvania
# GET []
# Try :  United States
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  London
# GET ['London']
# Try :  МSK
# GET []
# Try :
# Try :  Miami, USA
# GET ['Miami']
# Try :  Иркутск
# GET []
# Try :  Новосибирск
# GET []
# Try :  USA
# GET []
# Try :  New York, NY
# GET ['New York']
# Try :  Волгоград
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Miami, FL
# GET ['Miami']
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :
# Try :  سورية
# GET []
# Try :
# Try :
# Try :  Baltimore, MD
# GET ['Baltimore']
# Try :
# Try :  USA
# GET []
# Try :  حمص
# GET []
# Try :  Minnesota
# GET []
# Try :
# Try :
# Try :  Питер
# GET []
# Try :  Уфа
# GET []
# Try :  Питер
# GET []
# Try :
# Try :  LA
# GET []
# Try :  حلب
# GET []
# Try :  Ростов-На-Дону
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Санкт-петербург
# GET []
# Try :  usa
# GET []
# Try :  St.Petersburg
# GET []
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :  Russia
# GET ['Russia']
# Try :  Philadelhia
# GET []
# Try :  Baltimore, MD
# GET ['Baltimore']
# Try :  Oklahoma
# GET []
# Try :  СПБ
# GET []
# Try :  US
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Ватноград
# GET []
# Try :  Черемухи
# GET []
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Pittsburgh, PA
# GET ['Pittsburgh']
# Try :  Moscow
# GET ['Moscow']
# Try :  France
# GET []
# Try :
# Try :  North Port, FL
# GET ['North Port']
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  Омск
# GET []
# Try :  سوريا
# GET []
# Try :  Калининград
# GET []
# Try :  spb
# GET []
# Try :  Псков
# GET []
# Try :  USA
# GET []
# Try :  SPB
# GET []
# Try :  Омск
# GET []
# Try :  USA
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Coventry
# GET ['Coventry']
# Try :  Питер
# GET []
# Try :  Россия
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Kansas, USA
# GET ['Kansas']
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  Erfurt, Deutschland
# GET ['Erfurt']
# Try :  Вильнюс - Москва
# GET []
# Try :  USA
# GET []
# Try :  California, USA
# GET ['California']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Бутово
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Hessen, Deutschland
# GET ['Hessen']
# Try :  Российская Федерация
# GET []
# Try :  USA
# GET []
# Try :  Raleigh, North Carolina
# GET ['Raleigh']
# Try :  Сочи
# GET []
# Try :
# Try :  Columbus, Ohio
# GET ['Columbus', 'Ohio']
# Try :
# Try :  United States
# GET []
# Try :  Москва
# GET []
# Try :  US
# GET []
# Try :  USA
# GET []
# Try :  Miami
# GET ['Miami']
# Try :  Deutschland
# GET []
# Try :  لبنان
# GET []
# Try :  OH
# GET []
# Try :  Wisconsin, USA
# GET []
# Try :  hood
# GET []
# Try :  USA
# GET []
# Try :  МSK
# GET []
# Try :  Perm, Russia
# GET ['Russia']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Спб
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  Jackson
# GET ['Jackson']
# Try :
# Try :  Москва
# GET []
# Try :  SPB
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Третий Рим
# GET []
# Try :  سوريا
# GET []
# Try :
# Try :  LA
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Чебоксары
# GET []
# Try :  Казань
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Москва
# GET []
# Try :  Germany
# GET []
# Try :  Manhattan, NY
# GET ['Manhattan']
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  New York, NY
# GET ['New York']
# Try :  Москва
# GET []
# Try :
# Try :  Moscow, Russia
# GET ['Moscow', 'Russia']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Lebanon
# GET ['Lebanon']
# Try :  Los Gatos, California
# GET ['California']
# Try :  USA
# GET []
# Try :  piter
# GET []
# Try :  US
# GET []
# Try :
# Try :  Россия
# GET []
# Try :  Saint Petersburg
# GET ['Petersburg']
# Try :  USA
# GET []
# Try :
# Try :  МSK
# GET []
# Try :  Калининград
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Russia
# GET ['Russia']
# Try :
# Try :  USA
# GET []
# Try :  France
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Texas, USA
# GET []
# Try :  Austin
# GET ['Austin']
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  МSK
# GET []
# Try :  United States
# GET []
# Try :  Сочи
# GET []
# Try :  USA
# GET []
# Try :  Düsseldorf, Deutschland
# GET ['Düsseldorf']
# Try :  Saarbrücken, Deutschland
# GET ['Saarbrücken']
# Try :  МSK
# GET []
# Try :  Москва
# GET []
# Try :  Питер
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  سوريا
# GET []
# Try :  Memphis, TN
# GET ['Memphis']
# Try :  Омск
# GET []
# Try :
# Try :  Germany
# GET []
# Try :  Amerika
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  LA
# GET []
# Try :
# Try :  SF
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  New-York
# GET []
# Try :
# Try :  Донецк
# GET []
# Try :  Syria
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  Washington
# GET ['Washington']
# Try :  USA
# GET []
# Try :  Washington, DC
# GET ['Washington']
# Try :  Kansas
# GET []
# Try :  USA
# GET []
# Try :  СПБ
# GET []
# Try :
# Try :  Manchester
# GET []
# Try :  Выборг
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  LA
# GET []
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  St. Petersburg
# GET ['Petersburg']
# Try :
# Try :  Омск
# GET []
# Try :  New Haven
# GET ['New Haven']
# Try :  Chicago
# GET ['Chicago']
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  London
# GET ['London']
# Try :  Ferguson, MO
# GET ['Ferguson']
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  America
# GET ['America']
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  Новосибирск
# GET []
# Try :  Black America
# GET ['America']
# Try :  سوريا
# GET []
# Try :  Dresden, Sachsen
# GET ['Dresden', 'Sachsen']
# Try :  United States
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :
# Try :
# Try :  Chicago
# GET ['Chicago']
# Try :  Washington, DC
# GET ['Washington']
# Try :  United States
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Newark, NJ
# GET ['Newark']
# Try :  Washington, D.C.
# GET ['Washington']
# Try :  USA
# GET []
# Try :
# Try :  омск
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Запорожье
# GET []
# Try :  Москва, Россия
# GET []
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Липецк
# GET []
# Try :  Dallas
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :
# Try :  ATL
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Washington, D.C.
# GET ['Washington']
# Try :  Velikiy Novgorod, Russia
# GET ['Russia']
# Try :  USA
# GET []
# Try :  MN
# GET []
# Try :  دمشق
# GET []
# Try :
# Try :  Саратов )))
# GET []
# Try :
# Try :  Питер
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Омск, Россия
# GET []
# Try :  USA
# GET []
# Try :  UK
# GET []
# Try :  Phoenix
# GET ['Phoenix']
# Try :
# Try :  Питер
# GET []
# Try :  Germany
# GET []
# Try :  Москва
# GET []
# Try :
# Try :
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Казань
# GET []
# Try :  Minneapolis, MN
# GET []
# Try :
# Try :
# Try :  Philadelphia, PA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Oliva Pizza & Pasta // Amman
# GET ['Oliva']
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  NY City
# GET []
# Try :
# Try :  Мурманск
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  United States
# GET []
# Try :  Italy
# GET ['Italy']
# Try :  Russia
# GET ['Russia']
# Try :
# Try :  United States
# GET []
# Try :  Chelyabinsk, Russia
# GET ['Chelyabinsk', 'Russia']
# Try :  Москва
# GET []
# Try :
# Try :  Моска
# GET []
# Try :  Волгоград
# GET []
# Try :
# Try :  spb
# GET []
# Try :
# Try :  Texas
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Estados Unidos
# GET []
# Try :  Новосибирск
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Nebraska, USA
# GET []
# Try :  NY
# GET []
# Try :
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  San-Francisco
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  US
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  New York
# GET ['New York']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Москва
# GET []
# Try :  Washington, DC
# GET ['Washington']
# Try :  Grove City, Ohio
# GET ['Grove', 'Ohio']
# Try :
# Try :  US
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Arizona, USA
# GET []
# Try :  USA
# GET []
# Try :  Новосибирск
# GET []
# Try :  San Diego, United States
# GET ['San Diego']
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Питер
# GET []
# Try :
# Try :
# Try :  Нижний Новгород
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Новгород - СПб
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Київ
# GET []
# Try :
# Try :  Новосибирск
# GET []
# Try :  Россия
# GET []
# Try :  LA
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Мечта
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Хабаровск
# GET []
# Try :  РФ
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :  LA
# GET []
# Try :  saint p.
# GET []
# Try :  LA
# GET []
# Try :
# Try :  Pittsburgh
# GET ['Pittsburgh']
# Try :
# Try :  питер
# GET []
# Try :  Tallahassee
# GET ['Tallahassee']
# Try :  New Jersey, USA
# GET []
# Try :
# Try :
# Try :  Работа))
# GET []
# Try :  USA
# GET []
# Try :
# Try :  NY
# GET []
# Try :  Houston, TX
# GET ['Houston']
# Try :  Россия
# GET []
# Try :  Москва, Россия
# GET []
# Try :
# Try :  دمشق
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  America
# GET ['America']
# Try :  Moscow
# GET ['Moscow']
# Try :
# Try :  Rancho Rinconada, CA, USA
# GET []
# Try :
# Try :  NY
# GET []
# Try :  ростов-я-тону
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  Colorado
# GET ['Colorado']
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Нижний Новгород
# GET []
# Try :  US
# GET []
# Try :  Arizona
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Ташла
# GET []
# Try :  US
# GET []
# Try :  US
# GET []
# Try :
# Try :  Выборг
# GET []
# Try :  Beirut
# GET ['Beirut']
# Try :  Hollywood
# GET ['Hollywood']
# Try :
# Try :  New York, NY
# GET ['New York']
# Try :
# Try :  Россия
# GET []
# Try :  Phoenix
# GET ['Phoenix']
# Try :  Philadelphia
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Chicago
# GET ['Chicago']
# Try :  ID
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Milwaukee, WI
# GET ['Milwaukee']
# Try :  Питер
# GET []
# Try :  Guanica zona urbana, PR, USA
# GET ['Guanica']
# Try :  USA
# GET []
# Try :  питер
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :
# Try :  London, UK
# GET ['London']
# Try :  Новосибирск
# GET []
# Try :  Москва
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Новосибирск
# GET []
# Try :  Italy
# GET ['Italy']
# Try :  Мурманск
# GET []
# Try :
# Try :  Los-Angeles
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  ул. Ленина
# GET []
# Try :  Новосибирск
# GET []
# Try :  US
# GET []
# Try :  United States
# GET []
# Try :  Russia
# GET ['Russia']
# Try :
# Try :  Islamic States of America
# GET ['America']
# Try :  Москва
# GET []
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Питер
# GET []
# Try :
# Try :
# Try :  Новосибирск
# GET []
# Try :  New York
# GET ['New York']
# Try :  nyc
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  Киров
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Коломна
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Italia
# GET ['Italia']
# Try :  Санкт-Петербург
# GET []
# Try :  Eldorado at Santa Fe, NM, USA
# GET ['Eldorado']
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Омск
# GET []
# Try :  Москва
# GET []
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  Москва, Россия
# GET []
# Try :
# Try :  Москва
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :  Greensboro
# GET ['Greensboro']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Казань
# GET []
# Try :  United States
# GET []
# Try :  Macon, GA
# GET ['Macon']
# Try :  Philadelphia
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Washington
# GET ['Washington']
# Try :
# Try :
# Try :
# Try :  سوريا
# GET []
# Try :  спб
# GET []
# Try :
# Try :  Омск
# GET []
# Try :  Иваново
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Питер
# GET []
# Try :  Питер
# GET []
# Try :  NY
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Montgomery
# GET ['Montgomery']
# Try :
# Try :  Тула
# GET []
# Try :  Москва
# GET []
# Try :  Новгород
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Germany
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  USA
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Germany
# GET []
# Try :
# Try :  Washington, DC
# GET ['Washington']
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  Russia, Moscow
# GET ['Moscow', 'Russia']
# Try :  Damascus
# GET []
# Try :  Moscow, Russia
# GET ['Moscow', 'Russia']
# Try :  Петрозаводск
# GET []
# Try :  Philadelphia
# GET []
# Try :
# Try :  Екатеринбург
# GET []
# Try :  Питер
# GET []
# Try :  Hamburg, Deutschland
# GET ['Hamburg']
# Try :
# Try :  Москва
# GET []
# Try :  cleveland / ohio
# GET []
# Try :  Texas, USA
# GET []
# Try :  Москва, Россия
# GET []
# Try :  US
# GET []
# Try :  ✴Новгород✴
# GET []
# Try :  СПб
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  Мінск
# GET []
# Try :  Новосибирск
# GET []
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Сочи
# GET []
# Try :  Волгоград, Россия
# GET []
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :  Nashville
# GET ['Nashville']
# Try :  New York, USA
# GET ['New York']
# Try :  USA
# GET []
# Try :  Chicago, IL
# GET ['Chicago']
# Try :  Хабаровск, Россия
# GET []
# Try :  Brooklyn
# GET ['Brooklyn']
# Try :
# Try :  USA
# GET []
# Try :  Россия
# GET []
# Try :  омск
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Россия
# GET []
# Try :  Новосибирск
# GET []
# Try :  USA
# GET []
# Try :  МСК
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Washington, DC
# GET ['Washington']
# Try :  	Austin
# GET ['Austin']
# Try :  USA
# GET []
# Try :  Minnesota
# GET []
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :
# Try :  دمشق
# GET []
# Try :  US
# GET []
# Try :  USA
# GET []
# Try :  Екатеринбург
# GET []
# Try :  Georgia, USA
# GET []
# Try :  Россия
# GET []
# Try :  Liberty City
# GET ['Liberty']
# Try :  Новосибирск
# GET []
# Try :
# Try :
# Try :
# Try :  sin city
# GET []
# Try :
# Try :  Washington
# GET ['Washington']
# Try :  Одесса
# GET []
# Try :  USA
# GET []
# Try :  Россия
# GET []
# Try :  brooklyn
# GET []
# Try :  Redwood City, California
# GET ['California', 'Redwood']
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  NY
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Я везде
# GET []
# Try :  Greece
# GET []
# Try :
# Try :  Тверь
# GET []
# Try :  دمشق
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Germany
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  US
# GET []
# Try :  Cosmopolitanism
# GET []
# Try :  Москва
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  Manama, Bahrain
# GET ['Manama']
# Try :  екб
# GET []
# Try :  Chicago, IL
# GET ['Chicago']
# Try :  Philadelphia
# GET []
# Try :  Coventry
# GET ['Coventry']
# Try :  Витебск
# GET []
# Try :  Набережные Челны, Россия
# GET []
# Try :  Новосибирск
# GET []
# Try :
# Try :
# Try :
# Try :  Kuwait
# GET []
# Try :  Новосибирск
# GET []
# Try :  US
# GET []
# Try :  belgorod
# GET []
# Try :  USA
# GET []
# Try :  Тува
# GET []
# Try :  USA
# GET []
# Try :  Казань
# GET []
# Try :  United States
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Nizhniy Novgorod, Russia
# GET ['Russia']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  Newhustle
# GET []
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  US
# GET []
# Try :  United States
# GET []
# Try :  Новосибирск
# GET []
# Try :  moscow city
# GET []
# Try :  МSK
# GET []
# Try :  Волгоград
# GET []
# Try :  россия
# GET []
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  Новгород
# GET []
# Try :  Киев
# GET []
# Try :  Johnson City, New York
# GET ['New York', 'Johnson']
# Try :  Baltimore, MD
# GET ['Baltimore']
# Try :  Brussel, België
# GET []
# Try :
# Try :  Ярославль
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  سوريا
# GET []
# Try :  USA
# GET []
# Try :  Стамбул
# GET []
# Try :  United States
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :  Houston, TX
# GET ['Houston']
# Try :  Houston
# GET ['Houston']
# Try :  Москва
# GET []
# Try :  Сочи
# GET []
# Try :  USA
# GET []
# Try :  LA
# GET []
# Try :  СПб
# GET []
# Try :  Питер
# GET []
# Try :  New York, NY
# GET ['New York']
# Try :  Москва
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  United States
# GET []
# Try :  Philadelphia
# GET []
# Try :  Bremen, Deutschland
# GET ['Bremen']
# Try :  US
# GET []
# Try :  Saint Petersburg, Russia
# GET ['Petersburg', 'Russia']
# Try :  Москва
# GET []
# Try :  Питер
# GET []
# Try :  Москва, Россия
# GET []
# Try :  United States
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :
# Try :  Новосибирск
# GET []
# Try :  USA
# GET []
# Try :  North Carolina
# GET ['Carolina', 'North']
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Москва
# GET []
# Try :
# Try :  Beirut
# GET ['Beirut']
# Try :  Новгород
# GET []
# Try :
# Try :  Chicago
# GET ['Chicago']
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  New Hampshire
# GET ['New Hampshire']
# Try :  Мурманск
# GET []
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :  Ярославль
# GET []
# Try :
# Try :  Питер
# GET []
# Try :  United States
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Пушкин
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Germany
# GET []
# Try :  Москва
# GET []
# Try :  ARIZONA
# GET []
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :
# Try :  USA
# GET []
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  Челябинск
# GET []
# Try :  Москва
# GET []
# Try :  Россия
# GET []
# Try :  SPB
# GET []
# Try :  New Orleans, LA
# GET ['Orleans']
# Try :
# Try :  St.Petersburg
# GET []
# Try :  Москва
# GET []
# Try :  Новосибирск
# GET []
# Try :
# Try :  Москва
# GET []
# Try :
# Try :  LA
# GET []
# Try :  Москва
# GET []
# Try :  msk
# GET []
# Try :
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Washington, DC
# GET ['Washington']
# Try :
# Try :  Arizona
# GET []
# Try :  Arizona
# GET []
# Try :  Москва
# GET []
# Try :  Downtown, Atlanta
# GET ['Atlanta']
# Try :  San-Francisco
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Москва
# GET []
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  Москва
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Stonewall, TX
# GET ['Stonewall']
# Try :
# Try :  US
# GET []
# Try :
# Try :  Краснодар
# GET []
# Try :  عمان
# GET []
# Try :  Newcastle
# GET ['Newcastle']
# Try :  United States
# GET []
# Try :  Самара
# GET []
# Try :
# Try :  MN
# GET []
# Try :  Новосибирск, Россия
# GET []
# Try :  United States
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :  Newcastle
# GET ['Newcastle']
# Try :  USA
# GET []
# Try :  Казань
# GET []
# Try :  Новосибирск
# GET []
# Try :  saint P.
# GET []
# Try :  Ростов
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Россия
# GET []
# Try :  Москва, Россия
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Мечтовиль
# GET []
# Try :  Москва, Россия
# GET []
# Try :  USA
# GET []
# Try :  Kiel, Schleswig-Holstein
# GET ['Kiel']
# Try :  سورية
# GET []
# Try :  United States
# GET []
# Try :  Los Angeles, CA
# GET ['Los Angeles']
# Try :  Louisiana
# GET []
# Try :  New York City
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  Сочи
# GET []
# Try :  MSK SAO
# GET []
# Try :  Syria
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  msk
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  МSK
# GET []
# Try :  МСК
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  NY
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Россия
# GET []
# Try :
# Try :  Baltimore, MD
# GET ['Baltimore']
# Try :  Новгород
# GET []
# Try :  Омск
# GET []
# Try :  уфа
# GET []
# Try :  Washington D.C
# GET ['Washington']
# Try :  Wonderland
# GET []
# Try :
# Try :  Syria
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  United States
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :   Santa Barbara, California
# GET ['California', 'Santa']
# Try :  Москва
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  Zarqa, Jordan
# GET ['Jordan']
# Try :  Russia
# GET ['Russia']
# Try :
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  Новгород
# GET []
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Germany
# GET []
# Try :  USA
# GET []
# Try :  novgorod
# GET []
# Try :  USA
# GET []
# Try :  Oklahoma City
# GET ['Oklahoma City']
# Try :  United States
# GET []
# Try :  Питер
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  Los Alamos
# GET ['Alamos']
# Try :  حماة
# GET []
# Try :  US
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Москва
# GET []
# Try :  Rhode Island
# GET ['Island']
# Try :  Москва
# GET []
# Try :  SPb
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Новгород
# GET []
# Try :  москва
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  LA
# GET []
# Try :  Люберцы
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Man
# GET []
# Try :  Волгоград
# GET []
# Try :  USA
# GET []
# Try :  Memphis, TN
# GET ['Memphis']
# Try :
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  SPB
# GET []
# Try :  Phoenix
# GET ['Phoenix']
# Try :  Kansas, USA
# GET ['Kansas']
# Try :  Москва
# GET []
# Try :  Омск
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  LA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  South Carolina, USA
# GET []
# Try :  Серпухов
# GET []
# Try :  st.petersburg
# GET []
# Try :  vladik
# GET []
# Try :  МSK
# GET []
# Try :  Петербург
# GET []
# Try :  Chicago, IL
# GET ['Chicago']
# Try :  spb
# GET []
# Try :  СПб
# GET []
# Try :  Россия
# GET []
# Try :  United States
# GET []
# Try :
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Kansas City, MO
# GET ['Kansas']
# Try :  Москва
# GET []
# Try :
# Try :  МSK
# GET []
# Try :
# Try :  Saint Petersburg, Russia
# GET ['Petersburg', 'Russia']
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Brooklyn, NY
# GET ['Brooklyn']
# Try :
# Try :
# Try :  Brkln
# GET []
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :
# Try :  Fattyland
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Петроград
# GET []
# Try :  Красноярск
# GET []
# Try :  USA
# GET []
# Try :  Елец
# GET []
# Try :  Севастополь
# GET []
# Try :  Kuwait
# GET []
# Try :  Philadelphia
# GET []
# Try :  хогвортс
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  سوريا
# GET []
# Try :  Germany
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :
# Try :  Омск
# GET []
# Try :  st/petersburg
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :  Syria
# GET []
# Try :  San Francisco, CA
# GET ['San Francisco']
# Try :  Прага
# GET []
# Try :  United States
# GET []
# Try :  Брянск
# GET []
# Try :  Адлер
# GET []
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Киев
# GET []
# Try :  cанкт-петербург
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Montana
# GET ['Montana']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  New Jersey
# GET []
# Try :  Philadelphia
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :  Екатеринбург
# GET []
# Try :  Мариуполь
# GET []
# Try :
# Try :  Crimea, Russia
# GET ['Russia']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Germany
# GET []
# Try :
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  Moscow, Russia
# GET ['Moscow', 'Russia']
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Estados Unidos
# GET []
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :
# Try :  Montgomery, Ohio
# GET ['Montgomery', 'Ohio']
# Try :  USA
# GET []
# Try :  Новгород
# GET []
# Try :
# Try :
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :
# Try :  Madison
# GET ['Madison']
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  msk
# GET []
# Try :  Saint Petersburg, Russia
# GET ['Petersburg', 'Russia']
# Try :  USA
# GET []
# Try :  LA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Москва
# GET []
# Try :  Питер
# GET []
# Try :  Detroit, Michigan
# GET ['Detroit']
# Try :
# Try :  Cleveland, OH
# GET ['Cleveland']
# Try :  USA
# GET []
# Try :  Екатеринбург
# GET []
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Chicago
# GET ['Chicago']
# Try :  USA
# GET []
# Try :  россия
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  Туапсе, Москва
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  ATL, GA
# GET []
# Try :
# Try :  Питер
# GET []
# Try :  Саранск
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва, Россия
# GET []
# Try :  СПб
# GET []
# Try :  CA
# GET []
# Try :  Houston
# GET ['Houston']
# Try :  NY
# GET []
# Try :  Chicago, IL
# GET ['Chicago']
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  сейчас орел
# GET []
# Try :  Екатеринбург
# GET []
# Try :  USA
# GET []
# Try :  Texas, USA
# GET []
# Try :  NYC
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Phoenix
# GET ['Phoenix']
# Try :  USA
# GET []
# Try :  Germany
# GET []
# Try :  Albuquerque
# GET []
# Try :  Чебоксары
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Whitehall, Ohio
# GET ['Whitehall', 'Ohio']
# Try :  Липецк
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Брянск
# GET []
# Try :  حمص
# GET []
# Try :  Псков
# GET []
# Try :  USA
# GET []
# Try :  Нижний Новгород
# GET []
# Try :  Липецк
# GET []
# Try :  I AM A CITIZEN OF THE UNIVERSE
# GET []
# Try :  US
# GET []
# Try :
# Try :  Москва, Россия
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  Birmingham
# GET ['Birmingham']
# Try :  Birmingham
# GET ['Birmingham']
# Try :  Florida
# GET ['Florida']
# Try :  Baton Rouge, LA
# GET ['Rouge']
# Try :  Кронштадт
# GET []
# Try :  Cleve
# GET []
# Try :  Калининград
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  USA
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  Dallas
# GET []
# Try :  SPB
# GET []
# Try :  US
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Portland
# GET ['Portland']
# Try :  United States
# GET []
# Try :  Salem, Massachusetts
# GET ['Salem']
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Выборг
# GET []
# Try :  USA
# GET []
# Try :
# Try :  United States
# GET []
# Try :  Пермь
# GET []
# Try :  USA
# GET []
# Try :  San Francisco
# GET []
# Try :  New York
# GET ['New York']
# Try :  Houston, TX
# GET ['Houston']
# Try :  US
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  NY
# GET []
# Try :  USA
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Россия
# GET []
# Try :  Jacksonville
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Россия
# GET []
# Try :  Washington, D.C.
# GET ['Washington']
# Try :  Wonderland
# GET []
# Try :  Тамань
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  AL
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Петербург
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :  MSK
# GET []
# Try :  CA
# GET []
# Try :
# Try :   East Aurora, New York
# GET ['New York', 'East Aurora']
# Try :  New York City
# GET []
# Try :  Russia
# GET ['Russia']
# Try :  Vegas
# GET []
# Try :  Dallas, TX
# GET ['Dallas']
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  NY
# GET []
# Try :  Georgia
# GET []
# Try :  Houston, TX
# GET ['Houston']
# Try :
# Try :
# Try :  سورية
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Уфа
# GET []
# Try :  Киев
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Minneapolis, MN
# GET []
# Try :  Питер
# GET []
# Try :
# Try :  United States
# GET []
# Try :
# Try :  NY
# GET []
# Try :  МSK
# GET []
# Try :  Нижний Новгород
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Perm, Russia
# GET ['Russia']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Druid Hills, GA
# GET ['Hills']
# Try :  Stuttgart, Deutschland
# GET ['Stuttgart']
# Try :  Москва
# GET []
# Try :
# Try :
# Try :  Philadelphia
# GET []
# Try :  USA
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  سوريا
# GET []
# Try :  USA
# GET []
# Try :  Ohio, USA
# GET ['Ohio']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  ширкино
# GET []
# Try :  Сраратов
# GET []
# Try :  United Kingdom
# GET []
# Try :  اللاذقية
# GET []
# Try :
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  Houston, TX
# GET ['Houston']
# Try :  Atlanta
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :  Казань
# GET []
# Try :  баку
# GET []
# Try :  USA
# GET []
# Try :  California
# GET ['California']
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :  мой мир
# GET []
# Try :  moscow
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  Chicago
# GET ['Chicago']
# Try :
# Try :  Manchester
# GET []
# Try :  Pittsburgh, US
# GET ['Pittsburgh']
# Try :  Boston
# GET ['Boston']
# Try :  Новосиб
# GET []
# Try :  utah
# GET []
# Try :  AZ
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :
# Try :  Новгород
# GET []
# Try :  Syria
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  United States
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Екатеринбург
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Новосибирск
# GET []
# Try :  Москва
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  US
# GET []
# Try :
# Try :  Bronx, NY
# GET ['Bronx']
# Try :  Nevada
# GET ['Nevada']
# Try :  Краснодар
# GET []
# Try :  United States
# GET []
# Try :  Сочи, Россия
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  New York
# GET ['New York']
# Try :
# Try :  United States
# GET []
# Try :  Омск
# GET []
# Try :  Новосибирск
# GET []
# Try :  Cleveland, OH
# GET ['Cleveland']
# Try :  Калининград
# GET []
# Try :  МSK
# GET []
# Try :  سوريا
# GET []
# Try :
# Try :  Чебоксары
# GET []
# Try :  Москва
# GET []
# Try :
# Try :
# Try :  Florida
# GET ['Florida']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  СПБ
# GET []
# Try :
# Try :
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Germany
# GET []
# Try :
# Try :  London, England
# GET ['London', 'England']
# Try :  Москва
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Днепр, Украина
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Москва
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  USA
# GET []
# Try :  Петроград
# GET []
# Try :  NYC
# GET []
# Try :  USA
# GET []
# Try :  Стокгольм
# GET []
# Try :
# Try :  New York, NY
# GET ['New York']
# Try :  Murmansk, Russia
# GET ['Murmansk', 'Russia']
# Try :  USA, Atlanta
# GET ['Atlanta']
# Try :
# Try :  Екатеринбург
# GET []
# Try :  USA
# GET []
# Try :  МSK
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Boston
# GET ['Boston']
# Try :  Moscow, Russia
# GET ['Moscow', 'Russia']
# Try :  New York, USA
# GET ['New York']
# Try :  Birmingham
# GET ['Birmingham']
# Try :  Oklahoma, PA
# GET []
# Try :  Котлас
# GET []
# Try :  Cairo, Egypt
# GET ['Egypt', 'Cairo']
# Try :  Москва♥
# GET []
# Try :  United States
# GET []
# Try :  London, England
# GET ['London', 'England']
# Try :
# Try :  US
# GET []
# Try :  Москва
# GET []
# Try :  Egypt
# GET ['Egypt']
# Try :  Санкт-Петербург
# GET []
# Try :  US
# GET []
# Try :
# Try :  United States
# GET []
# Try :  Новгород
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :
# Try :  Moscow
# GET ['Moscow']
# Try :  US
# GET []
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :
# Try :  Las Vegas
# GET []
# Try :  Новгород
# GET []
# Try :
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Garden City, NY
# GET ['Garden']
# Try :  New-York
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :
# Try :  United States
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Weeki Wachee, Florida
# GET ['Florida']
# Try :  Atlanta
# GET ['Atlanta']
# Try :  С-Пб
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :
# Try :  NY
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :
# Try :  دمشق
# GET []
# Try :  USA
# GET []
# Try :  Miami
# GET ['Miami']
# Try :  ЕКБ
# GET []
# Try :  Новосибирск
# GET []
# Try :  New York City
# GET []
# Try :  New Jersey
# GET []
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Destin, Florida
# GET ['Destin', 'Florida']
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :   Milford, Ohio
# GET ['Milford', 'Ohio']
# Try :  United States
# GET []
# Try :  Newcastle
# GET ['Newcastle']
# Try :  USA
# GET []
# Try :  Millville village, OH, USA
# GET ['Millville']
# Try :  US
# GET []
# Try :  Cincinnati
# GET ['Cincinnati']
# Try :  Miami, FL
# GET ['Miami']
# Try :  МSK
# GET []
# Try :  Dallas
# GET []
# Try :  Riverside
# GET ['Riverside']
# Try :  Germany
# GET []
# Try :  Москва
# GET []
# Try :  Москва
# GET []
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  Москва
# GET []
# Try :  Stanwood city, WA, USA
# GET ['Stanwood']
# Try :  USA
# GET []
# Try :  Santa Monica
# GET ['Santa']
# Try :  Питер
# GET []
# Try :  Jackson
# GET ['Jackson']
# Try :
# Try :  Amman
# GET ['Amman']
# Try :
# Try :  NY
# GET []
# Try :
# Try :  United States
# GET []
# Try :
# Try :  Екатеринбург
# GET []
# Try :  USA
# GET []
# Try :
# Try :  NY
# GET []
# Try :  МSK
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :
# Try :  Houston, TX
# GET ['Houston']
# Try :  Российская Федерация
# GET []
# Try :  Россия
# GET []
# Try :  Москва
# GET []
# Try :  Волгоград, Вася!
# GET []
# Try :  Омск
# GET []
# Try :  USA
# GET []
# Try :
# Try :  United States
# GET []
# Try :  Jacksonville
# GET []
# Try :
# Try :  Saint-Peterburg
# GET []
# Try :  Новосибирск
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Washington
# GET ['Washington']
# Try :  New York, USA
# GET ['New York']
# Try :  Egypt
# GET ['Egypt']
# Try :  USA
# GET []
# Try :
# Try :   Albuquerque
# GET []
# Try :  Вологда
# GET []
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  Miami, FL
# GET ['Miami']
# Try :
# Try :  London
# GET ['London']
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Брянск
# GET []
# Try :  Usa
# GET ['Usa']
# Try :  USA
# GET []
# Try :  Colorado
# GET ['Colorado']
# Try :
# Try :  USA
# GET []
# Try :  Пушкино
# GET []
# Try :  USA
# GET []
# Try :  Dresden, Sachsen
# GET ['Dresden', 'Sachsen']
# Try :  USA
# GET []
# Try :  Cleveland, OH
# GET ['Cleveland']
# Try :  USA
# GET []
# Try :
# Try :  spb
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  Россия
# GET []
# Try :  Brooklyn, NY
# GET ['Brooklyn']
# Try :  Тула, Россия
# GET []
# Try :  United States
# GET []
# Try :  Россия
# GET []
# Try :
# Try :  Новосибирск
# GET []
# Try :  Россия
# GET []
# Try :  МSK
# GET []
# Try :  Красноярск
# GET []
# Try :  New York
# GET ['New York']
# Try :  Phoenix
# GET ['Phoenix']
# Try :  katamandu
# GET []
# Try :  Deutschland
# GET []
# Try :  МSK
# GET []
# Try :
# Try :  Columbia, SC
# GET ['Columbia']
# Try :  Hamburg, Deutschland
# GET ['Hamburg']
# Try :  USA
# GET []
# Try :
# Try :  Detroit
# GET ['Detroit']
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  Калуга, Россия
# GET []
# Try :  USA
# GET []
# Try :  San Francisco
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Воронеж
# GET []
# Try :  USA
# GET []
# Try :  Mn
# GET []
# Try :  حماة
# GET []
# Try :  Омск
# GET []
# Try :  SPB
# GET []
# Try :  USA
# GET []
# Try :  North Dakota
# GET ['North', 'Dakota']
# Try :  USA
# GET []
# Try :  Germany
# GET []
# Try :
# Try :  Симферополь
# GET []
# Try :  Белгород
# GET []
# Try :
# Try :  United States
# GET []
# Try :  US
# GET []
# Try :
# Try :  Chicago, IL
# GET ['Chicago']
# Try :  Москва, Россия
# GET []
# Try :  Lyon
# GET ['Lyon']
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Aurora, Illinois
# GET ['Aurora']
# Try :   Mexico
# GET ['Mexico']
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Новосибирск
# GET []
# Try :  USA
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Egypt
# GET ['Egypt']
# Try :  Москва
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  USA
# GET []
# Try :  Выборг
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Россия
# GET []
# Try :  Newcastle
# GET ['Newcastle']
# Try :  USA
# GET []
# Try :  Россия
# GET []
# Try :  Россия
# GET []
# Try :  INDIANAPOLIS, USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Питер
# GET []
# Try :  Волгоград, Россия
# GET []
# Try :  Краснодар
# GET []
# Try :  Portland
# GET ['Portland']
# Try :  United States
# GET []
# Try :  Miami
# GET ['Miami']
# Try :
# Try :
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  днищний дновгород
# GET []
# Try :
# Try :  Казань
# GET []
# Try :  Alaska
# GET []
# Try :
# Try :  San Diego, CA
# GET ['San Diego']
# Try :  Baltimore, MD
# GET ['Baltimore']
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Москва
# GET []
# Try :  Коломна
# GET []
# Try :  Az-Zarqa
# GET []
# Try :  Dallas
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва - Самара
# GET []
# Try :  Detroit
# GET ['Detroit']
# Try :  СПб
# GET []
# Try :  Germany
# GET []
# Try :  москва
# GET []
# Try :
# Try :  Пхеньян
# GET []
# Try :  The Big Apple
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :
# Try :  Liverpool
# GET ['Liverpool']
# Try :  Омск
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Кострома
# GET []
# Try :  Москва
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Подольск
# GET []
# Try :  United States
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Россия
# GET []
# Try :  SPb
# GET []
# Try :  LA
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  Memphis
# GET ['Memphis']
# Try :
# Try :  USA
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  Барнаул, Россия
# GET []
# Try :  новосибирск
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Москва
# GET []
# Try :  LA
# GET []
# Try :  Brussel, België
# GET []
# Try :  USA
# GET []
# Try :  Чебоксары
# GET []
# Try :  МSK
# GET []
# Try :  Воронеж
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Ohio
# GET ['Ohio']
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Тверь
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  alabama
# GET []
# Try :  United States
# GET []
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Днепр
# GET []
# Try :  California, USA
# GET ['California']
# Try :
# Try :  Москва
# GET []
# Try :
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  МSK
# GET []
# Try :
# Try :  Новосибирск
# GET []
# Try :  Москва
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Питер
# GET []
# Try :  Омск
# GET []
# Try :  USA
# GET []
# Try :  LA
# GET []
# Try :  Baltimore
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Новосибирск
# GET []
# Try :  Москва
# GET []
# Try :  United States
# GET []
# Try :  Калининград, Россия
# GET []
# Try :  USA
# GET []
# Try :  Саров
# GET []
# Try :  United States
# GET []
# Try :  Arizona
# GET []
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  New Orleans, LA
# GET ['Orleans']
# Try :
# Try :  saint-petersburg
# GET []
# Try :  Москва, Россия
# GET []
# Try :  USA
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Омск
# GET []
# Try :
# Try :  NYC
# GET []
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  USA
# GET []
# Try :  Петербург
# GET []
# Try :  ny
# GET []
# Try :  Таллин
# GET []
# Try :  Russia
# GET ['Russia']
# Try :  NY
# GET []
# Try :  USA
# GET []
# Try :  Ханты-Мансийск
# GET []
# Try :  Москва
# GET []
# Try :  Syria
# GET []
# Try :  New York, NY
# GET ['New York']
# Try :  Irkutsk
# GET ['Irkutsk']
# Try :  United States
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Россия
# GET []
# Try :  Москва
# GET []
# Try :  Новосибирск
# GET []
# Try :  NY
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Москва
# GET []
# Try :  Dallas, Texas
# GET ['Dallas']
# Try :  Москва
# GET []
# Try :  Tennessee, USA
# GET ['Tennessee']
# Try :  NY
# GET []
# Try :
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  Seattle
# GET ['Seattle']
# Try :  USA
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Новгород
# GET []
# Try :  Msk
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  United States
# GET []
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  Рязань
# GET []
# Try :  LA
# GET []
# Try :  Новосибирск, Россия
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Петербург
# GET []
# Try :  Москва
# GET []
# Try :  United States
# GET []
# Try :  Москва
# GET []
# Try :  LA
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  NY
# GET []
# Try :  Пермь
# GET []
# Try :  Киров
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  St-P
# GET []
# Try :
# Try :  El Paso, Texas
# GET []
# Try :  Москва
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Москва
# GET []
# Try :  Wichita, KS
# GET ['Wichita']
# Try :  LA
# GET []
# Try :  Москва
# GET []
# Try :  Питер
# GET []
# Try :  spb
# GET []
# Try :
# Try :  United States
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  Казань
# GET []
# Try :  Georgia, USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  United States
# GET []
# Try :  ID
# GET []
# Try :  Новгород
# GET []
# Try :  Republic of Chechnya, Russia
# GET ['Republic', 'Russia']
# Try :  Красти Бургер
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Питер
# GET []
# Try :  Сибирь матушка
# GET []
# Try :  Северная столица
# GET []
# Try :
# Try :  Нижний
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Тверское подворье
# GET []
# Try :  Paris
# GET ['Paris']
# Try :  СПБГПУ
# GET []
# Try :  New York
# GET ['New York']
# Try :  New York, NY
# GET ['New York']
# Try :  Germany
# GET []
# Try :  NH
# GET []
# Try :  Russia
# GET ['Russia']
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Москва
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Архангельск
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Нижний
# GET []
# Try :  ПЕТЕРБУРГ
# GET []
# Try :  United States
# GET []
# Try :  France
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Portland
# GET ['Portland']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  LA
# GET []
# Try :  USA
# GET []
# Try :  Saint-P
# GET []
# Try :  USA
# GET []
# Try :  Киев
# GET []
# Try :  TN
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  #РусскийМир
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Syria
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  USA, FL
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Ufa, Russia
# GET ['Ufa', 'Russia']
# Try :  Российская Федерация
# GET []
# Try :  Tomsk
# GET ['Tomsk']
# Try :  USA
# GET []
# Try :  Russia
# GET ['Russia']
# Try :  Los Angeles, CA
# GET ['Los Angeles']
# Try :
# Try :  Buffalo
# GET ['Buffalo']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Russia
# GET ['Russia']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Baton Rouge, LA
# GET ['Rouge']
# Try :  Colorado
# GET ['Colorado']
# Try :  Missouri, USA
# GET []
# Try :  NY
# GET []
# Try :  Berlin, Deutschland
# GET ['Berlin']
# Try :  Florida
# GET ['Florida']
# Try :  Dresden, Sachsen
# GET ['Dresden', 'Sachsen']
# Try :  USA
# GET []
# Try :  dreamland
# GET []
# Try :  New York, NY
# GET ['New York']
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  сжигай толерантный рай,слышишь
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Питер
# GET []
# Try :  Чебоксары, Россия
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Москва
# GET []
# Try :
# Try :  LA
# GET []
# Try :  USA
# GET []
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  USA
# GET []
# Try :  Кременчуг
# GET []
# Try :  Архангельск
# GET []
# Try :  USA
# GET []
# Try :  Syria
# GET []
# Try :  USA
# GET []
# Try :
# Try :  United States
# GET []
# Try :
# Try :  Volgograd
# GET ['Volgograd']
# Try :  العراق
# GET []
# Try :
# Try :  Чебоксары
# GET []
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :  Manhattan, NY
# GET ['Manhattan']
# Try :  Москва, Россия
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  Ростов
# GET []
# Try :  Manhattan, NY
# GET ['Manhattan']
# Try :  Москва (СССР - Россия)
# GET []
# Try :  USA
# GET []
# Try :
# Try :  New York
# GET ['New York']
# Try :  МSK
# GET []
# Try :  Москва
# GET []
# Try :  Тверь
# GET []
# Try :  Питер
# GET []
# Try :  Новокузнецк, Россия
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Jacksonville
# GET []
# Try :  New York
# GET ['New York']
# Try :  МSK
# GET []
# Try :  New York, NY
# GET ['New York']
# Try :  New York
# GET ['New York']
# Try :
# Try :
# Try :  USA
# GET []
# Try :  Белгород
# GET []
# Try :  ЦАО
# GET []
# Try :  Milano, Lombardia
# GET ['Milano']
# Try :  Москва - Лондон
# GET []
# Try :
# Try :
# Try :
# Try :  Новосибирск
# GET []
# Try :  Москва, Россия
# GET []
# Try :
# Try :
# Try :  دمشق
# GET []
# Try :  МSK
# GET []
# Try :  Madison
# GET ['Madison']
# Try :  Boston, MA
# GET ['Boston']
# Try :
# Try :  USA
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  амфетаминовая столица
# GET []
# Try :  United States
# GET []
# Try :  МSK
# GET []
# Try :  Сочи, Россия
# GET []
# ...
# Try :  USA
# GET []
# Try :  دمشق
# GET []
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Albuquerque, NM
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  Hollywood
# GET ['Hollywood']
# Try :  Moscow, Russia
# GET ['Moscow', 'Russia']
# Try :
# Try :  МSK
# GET []
# Try :  Москва
# GET []
# Try :  Houston
# GET ['Houston']
# Try :  Новосибирск
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :
# Try :  ☼Новосибчик☼
# GET []
# Try :  Ростов-на-Дону, Россия
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Красноярск
# GET []
# Try :  Oklahoma, USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  SPB
# GET []
# Try :  Украина
# GET []
# Try :  US
# GET []
# Try :  Таллин, Санкт-Петербург
# GET []
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :
# Try :  America
# GET ['America']
# Try :  Луганск
# GET []
# Try :  Чебоксары
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Москва, Россия
# GET []
# Try :  United States
# GET []
# Try :  МSK
# GET []
# Try :  Новосибирск
# GET []
# Try :  Syria
# GET []
# Try :
# Try :
# Try :  Richmond, VA
# GET ['Richmond']
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  Казань
# GET []
# Try :  Тула
# GET []
# Try :  Россия
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Albuquerque
# GET []
# Try :
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  United States
# GET []
# Try :  Донецк, Россия
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  New Orlean
# GET []
# Try :  SPB
# GET []
# Try :
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  France
# GET []
# Try :  New York
# GET ['New York']
# Try :  USA
# GET []
# Try :  Волгоград
# GET []
# Try :  Россия
# GET []
# Try :  Washington, DC
# GET ['Washington']
# Try :  Москва
# GET []
# Try :
# Try :  New York City
# GET []
# Try :  New York City
# GET []
# Try :  Ростов-на-Дону, Россия
# GET []
# Try :  Чебоксары
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  2148
# GET []
# Try :  New-York
# GET []
# Try :  Alaska
# GET []
# Try :  Texas, USA
# GET []
# Try :  Волгоград
# GET []
# Try :  USA
# GET []
# Try :  Delaware, USA
# GET ['Delaware']
# Try :  Syria
# GET []
# Try :  Los Angeles, CA
# GET ['Los Angeles']
# Try :  Egypt
# GET ['Egypt']
# Try :  US
# GET []
# Try :  USA
# GET []
# Try :  New York
# GET ['New York']
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  Петербург
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  الدمام
# GET []
# Try :
# Try :  С.Петербург
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  سوريا
# GET []
# Try :  Italia
# GET ['Italia']
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :  New York
# GET ['New York']
# Try :  US
# GET []
# Try :  Челябинск
# GET []
# Try :
# Try :
# Try :  Syria
# GET []
# Try :  USA
# GET []
# Try :  France
# GET []
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Москва
# GET []
# Try :
# Try :  USA
# GET []
# Try :  ♠Питер♠
# GET []
# Try :  City of Cleveland, USA
# GET ['Cleveland']
# Try :  United States
# GET []
# Try :
# Try :  Boston
# GET ['Boston']
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  Россия
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :
# Try :  Киров
# GET []
# Try :
# Try :  Москва
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Омск
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Россия
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  California
# GET ['California']
# Try :  Воронеж, Россия
# GET []
# Try :
# Try :
# Try :  United States
# GET []
# Try :  New - York
# GET ['York']
# Try :  Москва
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Чебоксары
# GET []
# Try :  New York, NY
# GET ['New York']
# Try :  Россия
# GET []
# Try :  Россия
# GET []
# Try :  New York
# GET ['New York']
# Try :  Москва, Россия
# GET []
# Try :
# Try :  Петрозаводск
# GET []
# Try :  Омск
# GET []
# Try :  USA
# GET []
# Try :
# Try :  United States
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  Волгодонск, Россия
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  Хабаровск
# GET []
# Try :  USA
# GET []
# Try :  Poland
# GET ['Poland']
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :
# Try :  NY
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  United States
# GET []
# Try :  Москва
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Красноярск
# GET []
# Try :  Питер
# GET []
# Try :  Питер
# GET []
# Try :  United States
# GET []
# Try :
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Курск
# GET []
# Try :
# Try :
# Try :
# Try :  Москва
# GET []
# Try :  US
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Portland
# GET ['Portland']
# Try :  US
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :
# Try :
# Try :  La Junta, Colorado
# GET ['Colorado']
# Try :  USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Вся Россия
# GET []
# Try :  Aleppo
# GET ['Aleppo']
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  United States
# GET []
# Try :  Paris, France
# GET ['Paris']
# Try :  Москва
# GET []
# Try :
# Try :  Омск
# GET []
# Try :  Charleston, SC
# GET ['Charleston']
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Екатеринбург
# GET []
# Try :  Москва
# GET []
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :
# Try :
# Try :  SPb♥○•°•☆
# GET []
# Try :  СПб
# GET []
# Try :  МСК
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  حلب
# GET []
# Try :
# Try :
# Try :  Egypt
# GET ['Egypt']
# Try :  Germany
# GET []
# Try :  Washington
# GET ['Washington']
# Try :  Rhode island
# GET []
# Try :  USA
# GET []
# Try :  Екатеринбург...
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :  Пермь
# GET []
# Try :  Birmingham
# GET ['Birmingham']
# Try :  Москва
# GET []
# Try :  Одинцово
# GET []
# Try :  LA
# GET []
# Try :  US
# GET []
# Try :  Germany
# GET []
# Try :  Jersey
# GET ['Jersey']
# Try :  WA
# GET []
# Try :  Саратов
# GET []
# Try :  syria
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Jacksonville
# GET []
# Try :  Москва Белокаменная
# GET []
# Try :  МSK
# GET []
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Estados Unidos
# GET []
# Try :  United States
# GET []
# Try :  Orlando, FL
# GET ['Orlando']
# Try :  Москва
# GET []
# Try :
# Try :  spb
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Orlando
# GET ['Orlando']
# Try :  Санкт-Петербург
# GET []
# Try :  portland
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Новосибирск
# GET []
# Try :
# Try :  Москва, Россия
# GET []
# Try :  МSK
# GET []
# Try :
# Try :  Moscow
# GET ['Moscow']
# Try :  Россия
# GET []
# Try :  Питер
# GET []
# Try :  Italia
# GET ['Italia']
# Try :  Вологда
# GET []
# Try :
# Try :  New York, NY
# GET ['New York']
# Try :
# Try :  Сестрорецк, Россия
# GET []
# Try :  US
# GET []
# Try :  Нижний Новогород
# GET []
# Try :  United States
# GET []
# Try :
# Try :  mother America
# GET ['America']
# Try :  Брянск
# GET []
# Try :  Krasnoyarsk
# GET ['Krasnoyarsk']
# Try :
# Try :  USA
# GET []
# Try :  Питер
# GET []
# Try :  СПБ
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  ★москва
# GET []
# Try :  МSK
# GET []
# Try :  Ростов
# GET []
# Try :
# Try :  New-York
# GET []
# Try :  Челны
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  US
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Украина
# GET []
# Try :
# Try :  Germany
# GET []
# Try :  Washington, D.C.
# GET ['Washington']
# Try :  Boston
# GET ['Boston']
# Try :  SF
# GET []
# Try :  Краснодар
# GET []
# Try :  Egypt
# GET ['Egypt']
# Try :  USA
# GET []
# Try :  Texas, USA
# GET []
# Try :  Columbia, SC
# GET ['Columbia']
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :  Germany
# GET []
# Try :  Москва
# GET []
# Try :  Brunswick, ME, USA
# GET ['Brunswick']
# Try :  Texas, USA
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва, Россия
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  NJ
# GET []
# Try :  USA
# GET []
# Try :  London
# GET ['London']
# Try :  МSK
# GET []
# Try :  Россия
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Miami, FL
# GET ['Miami']
# Try :  Санкт-Петербург
# GET []
# Try :  Louisville
# GET ['Louisville']
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  Москва
# GET []
# Try :  Волгоград
# GET []
# Try :  USA
# GET []
# Try :  Philly
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  United States
# GET []
# Try :
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :  اللاذقية
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  London
# GET ['London']
# Try :  Moscow-City
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Омск
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  New York
# GET ['New York']
# Try :
# Try :  Калининград
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  Houston
# GET ['Houston']
# Try :  Красноярск
# GET []
# Try :  Amman
# GET ['Amman']
# Try :  United States
# GET []
# Try :  Омск
# GET []
# Try :
# Try :  USA
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Москва
# GET []
# Try :  Fowler, California
# GET ['California', 'Fowler']
# Try :  USA
# GET []
# Try :  Penza
# GET ['Penza']
# Try :  Chicago
# GET ['Chicago']
# Try :  Ростов
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Germany
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Севастополь
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  Jacksonville
# GET []
# Try :  Москва
# GET []
# Try :  МСКВА
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Чебоксары
# GET []
# Try :  US
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Омск
# GET []
# Try :
# Try :  Moscow
# GET ['Moscow']
# Try :  Чита
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  Россия
# GET []
# Try :  US
# GET []
# Try :  City of San Antonio, TX
# GET ['San Antonio']
# Try :  Лос-Питербургос
# GET []
# Try :  USA
# GET []
# Try :  Новгород
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  МSK
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Los Angeles, CA
# GET ['Los Angeles']
# Try :
# Try :  МSK
# GET []
# Try :  Atlanta, Georgia
# GET ['Atlanta']
# Try :  Москва - столица
# GET []
# Try :
# Try :  Россия
# GET []
# Try :  Чебоксары
# GET []
# Try :  Владик ДВФУ
# GET []
# Try :  KN
# GET []
# Try :  City of Phoenix, Arizona
# GET ['Phoenix']
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  Омск
# GET []
# Try :
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Курск
# GET []
# Try :
# Try :  us
# GET []
# Try :  Ростов
# GET []
# Try :  Тверь
# GET []
# Try :  USA
# GET []
# Try :  Омск
# GET []
# Try :  Boston
# GET ['Boston']
# Try :  United States
# GET []
# Try :  МSK
# GET []
# Try :  USA
# GET []
# Try :  Новгород
# GET []
# Try :  Симферополь
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Washington D.C
# GET ['Washington']
# Try :  Washington, DC
# GET ['Washington']
# Try :
# Try :  Саратов
# GET []
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  USA
# GET []
# Try :  Washington, DC
# GET ['Washington']
# Try :
# Try :  Тула, Россия
# GET []
# Try :
# Try :  USA
# GET []
# Try :  arkansas
# GET []
# Try :  USA
# GET []
# Try :  Ростов-на-Дону
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург, Россия
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  Новгород
# GET []
# Try :  Москва
# GET []
# Try :  United States
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Moscow
# GET ['Moscow']
# Try :
# Try :
# Try :  Потсдам
# GET []
# Try :  Winchester, Virginia
# GET ['Virginia']
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  Сочи
# GET []
# Try :  Frankfurt am Main, Hessen
# GET ['Hessen']
# Try :
# Try :  Москва
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  US
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  MSK
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Симферополь
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  الأردن
# GET []
# Try :  Омск
# GET []
# Try :  Питер
# GET []
# Try :  New-York
# GET []
# Try :  Love Town
# GET []
# Try :  AL
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  РФ
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  Nashville
# GET ['Nashville']
# Try :  Санкт-Петербург
# GET []
# Try :  NY
# GET []
# Try :  ny
# GET []
# Try :  СПБ
# GET []
# Try :  USA
# GET []
# Try :  United States
# GET []
# Try :
# Try :  Новосибирск
# GET []
# Try :  Тверь
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :  Омск
# GET []
# Try :  USA
# GET []
# Try :  Chicago
# GET ['Chicago']
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  Washington, DC
# GET ['Washington']
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  USA
# GET []
# Try :  NY
# GET []
# Try :  Los Angeles, CA
# GET ['Los Angeles']
# Try :  USA
# GET []
# Try :
# Try :  New York, USA
# GET ['New York']
# Try :  New York City
# GET []
# Try :  Россия Санкт-Петербург
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :  Санкт-Петербург
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  USA
# GET []
# Try :
# Try :
# Try :  AMERICA
# GET []
# Try :  Germany
# GET []
# Try :  НН
# GET []
# Try :
# Try :
# Try :  Moscow, Russia
# GET ['Moscow', 'Russia']
# Try :  Нижний Новгород
# GET []
# Try :  San-Francisco
# GET []
# Try :  USA
# GET []
# Try :  Miami
# GET ['Miami']
# Try :  Новосибирск
# GET []
# Try :  Москва
# GET []
# Try :  Омск
# GET []
# Try :
# Try :  Chicago, IL
# GET ['Chicago']
# Try :  USA
# GET []
# Try :  Russia
# GET ['Russia']
# Try :  Houston, TX
# GET ['Houston']
# Try :  Florida, USA
# GET ['Florida']
# Try :  دمشق
# GET []
# Try :
# Try :  garage
# GET []
# Try :  USA
# GET []
# Try :  Кемерово
# GET []
# Try :  USA
# GET []
# Try :  НН
# GET []
# Try :
# Try :  France
# GET []
# Try :  italia
# GET []
# Try :  Москва, Россия
# GET []
# Try :  Salt Lake City
# GET ['Lake City', 'Salt']
# Try :  Venice, California
# GET ['Venice', 'California']
# Try :
# Try :  Москва
# GET []
# Try :
# Try :  Adler
# GET []
# Try :  Питер
# GET []
# Try :  Москва
# GET []
# Try :  Киев
# GET []
# Try :  Питер
# GET []
# Try :  USA
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Тула
# GET []
# Try :  МСК
# GET []
# Try :  Moscow
# GET ['Moscow']
# Try :  СПб
# GET []
# Try :  France
# GET []
# Try :  United States
# GET []
# Try :  USA
# GET []
# Try :  سوريا
# GET []
# Try :  مصر
# GET []
# Try :
# Try :  Kansas, USA
# GET ['Kansas']
# Try :
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :  Пермь
# GET []
# Try :  Нижний Новгород
# GET []
# Try :  Ярославль
# GET []
# Try :  Syria
# GET []
# Try :  Los Angeles
# GET ['Los Angeles']
# Try :
# Try :  NH
# GET []
# Try :
# Try :
# Try :
# Try :
# Try :  Omsk, Russia
# GET ['Omsk', 'Russia']
# Try :  Томск
# GET []
# Try :  USA
# GET []
# Try :  Новгород
# GET []
# Try :  Atlanta, GA
# GET ['Atlanta']
# Try :  USA
# GET []
# Try :
# Try :  NH
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :
# Try :
# Try :  Germany
# GET []
# Try :  Syria
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  USA
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Coventry
# GET ['Coventry']
# Try :  Россия, Казань
# GET []
# Try :  New York, USA
# GET ['New York']
# Try :  United States
# GET []
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Санкт-Петербург
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  United States
# GET []
# Try :  US
# GET []
# Try :
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :  USA
# GET []
# Try :
# Try :
# Try :
# Try :  Atlanta
# GET ['Atlanta']
# Try :  Вологда
# GET []
# Try :
# Try :  USA
# GET []
# Try :  US
# GET []
# Try :  Chicago
# GET ['Chicago']
# Try :
# Try :  New Jersey
# GET []
# Try :   Kansas
# GET []
# Try :
# Try :  Russia
# GET ['Russia']
# Try :  Россия
# GET []
# Try :
# Try :  United States
# GET []
# Try :  Boston
# GET ['Boston']
# Try :
# Try :  Москва
# GET []
# Try :  LA
# GET []
# Try :  Новгород
# GET []
# Try :
# Try :
# Try :  Kansas City, MO
# GET ['Kansas']
# Try :  Berlin, Deutschland
# GET ['Berlin']
# Try :  Чебоксары
# GET []
# Try :
# Try :  Москва
# GET []
# Try :  Волгоград
# GET []
# Try :  Baton Rouge, LA
# GET ['Rouge']
# Try :  USA
# GET []
# Try :
# Try :  سوريا
# GET []
# Try :  Санкт-Петербург
# GET []
# Try :  Москва
# GET []
# Try :  Philadelphia
# GET []
# Try :
# Try :  United States
# GET []
# Try :
# Try :  Texas, USA
# GET []
# Try :  USA
# GET []
# Try :  Москва
# GET []
# Try :  London, England
# GET ['London', 'England']
# Try :  New York
# GET ['New York']
# Try :  Egypt
# GET ['Egypt']
# Try :  Chicago
# GET ['Chicago']
# Try :  Нягань
# GET []
# Try :
# Try :  USA
# GET []
# Try :  Chicago
# GET ['Chicago']
# Try :  Stavropol, Russia
# GET ['Stavropol', 'Russia']
# Try :  USA
# GET []
# Try :  Ленинград
# GET []
# Try :
# Try :  New York, NY
# GET ['New York']
# Try :  Санкт-Петербург
# GET []
# Try :
# Try :  МSK
# GET []
# Try :
# Try :  US
# GET []

# %%
users['city'] = [str(x).split(',')[0].strip() for x in users['user_reported_location']]

# %%
#users['country'] = [str(x).split(',')[0].strip() for x in users['user_reported_location']]

# %%
users.loc[~users['user_reported_location'].str.contains(',', na=False),'city'] = np.nan

# %%
users[['city', 'user_reported_location']]
# Out:
#                       city        user_reported_location
# 0                      NaN                           USA
# 1                      NaN                          Раша
# 2     Чеченская республика  Чеченская республика, Россия
# 3                      NaN                            US
# 4                      NaN
# 5                      NaN
# 6                      NaN                           USA
# 7                      NaN                           USA
# 8                   Camden                    Camden, NJ
# 9                      NaN                        Dallas
# 10                     NaN
# 11                     NaN
# 12                     NaN                       Madison
# 13                     NaN                           USA
# 14                     NaN                      Мурманск
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN                       Germany
# 19                     NaN                        Alaska
# 20                 Chester                   Chester, PA
# 21                     NaN                         Питер
# 22                     NaN                        Москва
# 23                     NaN
# 24                     NaN                         سوريا
# 25                     NaN                  Pennsylvania
# 26                     NaN
# 27                     NaN                            US
# 28                     NaN
# 29                     NaN                           USA
# ...                    ...                           ...
# 3578                   NaN                           USA
# 3579                   NaN
# 3580                   NaN                         سوريا
# 3581                   NaN               Санкт-Петербург
# 3582                   NaN                        Москва
# 3583                   NaN                  Philadelphia
# 3584                   NaN
# 3585                   NaN                 United States
# 3586                   NaN
# 3587                 Texas                    Texas, USA
# 3588                   NaN                           USA
# 3589                   NaN                        Москва
# 3590                London               London, England
# 3591                   NaN                      New York
# 3592                   NaN                         Egypt
# 3593                   NaN                       Chicago
# 3594                   NaN                        Нягань
# 3595                   NaN
# 3596                   NaN                           USA
# 3597                   NaN                       Chicago
# 3598             Stavropol             Stavropol, Russia
# 3599                   NaN                           USA
# 3600                   NaN                     Ленинград
# 3601                   NaN
# 3602              New York                  New York, NY
# 3603                   NaN               Санкт-Петербург
# 3604                   NaN
# 3605                   NaN                           МSK
# 3606                   NaN
# 3607                   NaN                            US
#
# [3608 rows x 2 columns]

# %% [markdown]
# ## Translate and reformat user location data

# %%
users['location'] = users.user_reported_location.replace({  'Волгоград':'Volgograd, Russia','Egypt':'N/A, Egypt',
                                                            'Ростов':'Rostov-on-Don, Russia','Baltimore, MD':'Baltimore, United States','London':'London, England','Jacksonville':'Jacksonville, United States',
                                                            'Moscow':'Moscow, Russia', 'Петербург':'Saint Petersburg, Russia','New York City':'New York, United States', 'Arizona':'Phoenix, United States',
                                                            'Germany':'N/A, Germany','Санкт-Петербург, Россия':'Saint Petersburg, Russia','Нижний Новгород':'Nizhny Novgorod, Russia','Тверь':'Tver, Russia','Киев':'Kiev, Ukraine',
                                                            'دمشق':'Damascus, Syria','spb':'SPB','Estados Unidos':'N/A, United States','Estados Unidos':'Volgograd, Russia',
                                                            'Казань':'Kazan, Russia','Екатеринбург':'Yekaterinburg, Russia', 'СПБ':'Saint Petersburg, Russia','СПб':'Saint Petersburg, Russia','Washington, D.C.': 'Washington DC, United States',
                                                            'Houston, TX':'Houston, United States','Miami, FL': 'Miami, United States','Texas, USA':'Texas, United States','Washington': 'Washington DC, United States',
                                                            'France': 'N/A, France','Phoenix':'Phoenix, United States','Chicago, IL':'Chicago, United States','Washington, DC': 'Washington D.C, United States',
                                                            'Philadelphia':'Philadelphia, United States'  ,'Chicago':'Chicago, United States','Washington, D.C': 'Washington DC, United States',
                                                            'Чебоксары':'Cheboksary, Russia', 'سوريا':'N/A, Syria','Syria':'N/A, Syria', 'New-York':'New York, United States', 
                                                            'Atlanta' :'Atlanta, United States','LA' :'Los Angeles, United States','Los Angeles' :'Los Angeles, United States','Los Angeles, CA' :'Los Angeles, United States',
                                                            'Boston':'Boston, United States','Омск':'Omsk, Russia','New York, NY':'New York, United States',
                                                            'New York':'New York, United States', 'NY':'New York, United States', 'Новгород':'Veliky Novgorod, Russia', 
                                                            'Москва, Россия':'Moscow, Russia','Новосибирск': 'Novosibirsk, Russia', 'Россия' :'N/A, Russia' ,'Russia' :'N/A, Russia' ,
                                                            'New York, USA' :'New York, United States'   ,'Atlanta, GA' :'Atlanta, United States',
                                                            'Lichfield\t':'Lichfield, England', 'Istanbul via Liverpool': 'Liverpool, England', 'United States':'N/A, United States', 
                                                            'US':'N/A, United States', 'USA':'N/A, United States', 'Москва':'Moscow, Russia',
                                                            'Моscow':'Moscow, Russia', 'Санкт-Петербург':'Saint Petersburg, Russia', 'Питер':'Saint Petersburg, Russia'})

# %%
# For accounts without city specified, assume to be the capital of the country
users['location'] = users.location.replace({'N/A, Egypt':'Cairo, Egypt', 'N/A, Syria':'Damascus, Syria', 'N/A, France':'Paris, France', 'N/A, Germany':'Berlin, Germany'    ,'N/A, Russia':'Moscow, Russia'  ,'N/A, United States':'Washington, D.C., United States','Washington DC, United States':'Washington, D.C., United States', 'Washington D.C, United States':'Washington, D.C., United States' })

# %% [markdown]
# ## Location count by cities

# %%
location_count = pd.crosstab(index=users['location'],   columns="count").sort_values(by=['count'], ascending=False)

# %%
location_count.reset_index(level=0, inplace=True)

# %%
# Get the cities with more than 5 users and exclude invalid cities (MSK, SPB)

# %%
most_frequent = location_count[(location_count['count'] > 5) & (location_count['location'] != 'МSK') & (location_count['location']!='SPB')]

# %% [markdown]
# ### Parse country from location

# %%
most_frequent['country'] = [str(x).split(',')[-1].strip() for x in most_frequent['location']]
# Out:
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# glimpse of the data
most_frequent
# Out:
# col_0                         location  count        country
# 0      Washington, D.C., United States    871  United States
# 1                       Moscow, Russia    373         Russia
# 2             Saint Petersburg, Russia    178         Russia
# 3              New York, United States    124  United States
# 4               Atlanta, United States     89  United States
# 5           Los Angeles, United States     51  United States
# 6                      Damascus, Syria     41          Syria
# 7                  Novosibirsk, Russia     38         Russia
# 9              Veliky Novgorod, Russia     36         Russia
# 10                        Omsk, Russia     32         Russia
# 11                     Berlin, Germany     30        Germany
# 12               Boston, United States     24  United States
# 13              Chicago, United States     20  United States
# 14                  Cheboksary, Russia     17         Russia
# 16                   Volgograd, Russia     16         Russia
# 17              Phoenix, United States     15  United States
# 18                       Kazan, Russia     12         Russia
# 19               Yekaterinburg, Russia     11         Russia
# 20                       Paris, France     11         France
# 21         Philadelphia, United States     10  United States
# 22                     London, England     10        England
# 23                        Cairo, Egypt      8          Egypt
# 24             Nizhny Novgorod, Russia      8         Russia
# 25                        Tver, Russia      7         Russia
# 26                Texas, United States      7  United States
# 27                       Kiev, Ukraine      7        Ukraine
# 28              Houston, United States      7  United States
# 29                Miami, United States      7  United States
# 30               Rostov-on-Don, Russia      6         Russia

# %% [markdown]
# ### Get the country distribution of user accounts

# %%
countries_cnt = most_frequent.groupby(['country']).sum().sort_values(by='count', ascending = False)

# %%
countries_cnt.reset_index(level=0, inplace=True)

# %% [markdown]
# ## Map the country distribution on world map

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="twitter_bot_analysis")

# %%
# Get the long and lat coordinates of countries
countries_cnt['long'] = [geolocator.geocode(str(x)).longitude for x in countries_cnt['country']]

# %%
countries_cnt['lat'] = [geolocator.geocode(str(x)).latitude for x in countries_cnt['country']]

# %%
# Glimpse at country distribution
countries_cnt
# Out:
# col_0        country  count        long        lat
# 0      United States   1225 -100.445882  39.783730
# 1             Russia    734   97.745306  64.686314
# 2              Syria     41   39.049411  34.640186
# 3            Germany     30   10.423447  51.083420
# 4             France     11    1.888334  46.603354
# 5            England     10   -0.540240  52.795479
# 6              Egypt      8   29.267547  26.254049
# 7            Ukraine      7   31.271832  49.487197

# %% [markdown]
# ### Generate map

# %%
# import the library
import folium

# Make an empty map
m = folium.Map(location=[0,0], zoom_start=2)
 
# I can add marker one by one on the map
for i in range(0,len(countries_cnt)):
   folium.Circle( location=[countries_cnt.iloc[i]['lat'], countries_cnt.iloc[i]['long']],      popup=countries_cnt.iloc[i]['country'] + ' : ' + str(countries_cnt.iloc[i]['count']),
      radius=float(countries_cnt.iloc[i]['count']*1000),      color='crimson',    fill_color='crimson',  fill=True).add_to(m)
 
# Save it as html
m.save('mymap_countries.html')

# %% [markdown]
# ## Map user account distribution by cities on world map

# %%
# Get the long and lat coordinates for cities
most_frequent['long'] = [geolocator.geocode(str(x)).longitude for x in most_frequent['location']]
most_frequent['lat'] = [geolocator.geocode(str(x)).latitude for x in most_frequent['location']]
# Out:
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# c:\users\lizda\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %% [markdown]
# ### Glimpse at cities distribution

# %%
most_frequent
# Out:
# col_0                         location  count        country        long  \
# 0      Washington, D.C., United States    871  United States  -77.036563
# 1                       Moscow, Russia    373         Russia   37.617494
# 2             Saint Petersburg, Russia    178         Russia   30.316229
# 3              New York, United States    124  United States  -73.987156
# 4               Atlanta, United States     89  United States  -84.390185
# 5           Los Angeles, United States     51  United States -118.242767
# 6                      Damascus, Syria     41          Syria   36.309581
# 7                  Novosibirsk, Russia     38         Russia   82.923451
# 9              Veliky Novgorod, Russia     36         Russia   31.275786
# 10                        Omsk, Russia     32         Russia   73.371529
# 11                     Berlin, Germany     30        Germany   13.388860
# 12               Boston, United States     24  United States  -71.058291
# 13              Chicago, United States     20  United States  -87.624421
# 14                  Cheboksary, Russia     17         Russia   47.244960
# 16                   Volgograd, Russia     16         Russia   44.516804
# 17              Phoenix, United States     15  United States -112.077346
# 18                       Kazan, Russia     12         Russia   49.124227
# 19               Yekaterinburg, Russia     11         Russia   60.608250
# 20                       Paris, France     11         France    2.351499
# 21         Philadelphia, United States     10  United States  -75.163575
# 22                     London, England     10        England   -0.127647
# 23                        Cairo, Egypt      8          Egypt   31.243666
# 24             Nizhny Novgorod, Russia      8         Russia   44.003506
# 25                        Tver, Russia      7         Russia   35.920828
# 26                Texas, United States      7  United States  -99.512099
# 27                       Kiev, Ukraine      7        Ukraine   30.524104
# 28              Houston, United States      7  United States  -95.367697
# 29                Miami, United States      7  United States  -80.193659
# 30               Rostov-on-Don, Russia      6         Russia   39.716486
#
# col_0        lat
# 0      38.895009
# 1      55.750446
# 2      59.938732
# 3      40.730862
# 4      33.749099
# 5      34.053683
# 6      33.513070
# 7      55.028217
# 9      58.520986
# 10     54.991375
# 11     52.517037
# 12     42.360253
# 13     41.875562
# 14     56.130719
# 16     48.710678
# 17     33.448587
# 18     55.782355
# 19     56.839104
# 20     48.856610
# 21     39.952415
# 22     51.507322
# 23     30.048819
# 24     56.328571
# 25     56.858675
# 26     31.816038
# 27     50.450064
# 28     29.758938
# 29     25.774266
# 30     47.224695

# %% [markdown]
# ## Generate map

# %%
# import the library
import folium

# Make an empty map
m = folium.Map(location=[0,0], zoom_start=2)
 
# I can add marker one by one on the map
for i in range(0,len((most_frequent))):
   folium.Circle( location=[most_frequent.iloc[i]['lat'], most_frequent.iloc[i]['long']],      popup=most_frequent.iloc[i]['location'] + ' : ' + str(most_frequent.iloc[i]['count']),
      radius=float(most_frequent.iloc[i]['count']*500),      color='crimson',    fill_color='crimson',  fill=True).add_to(m)
 
# Save it as html
m.save('mymap.html')

# %%
## Future Question
####   From the location analysis, we can see that most accounts reported to be within US though they are from foreign information operations. 
####    In the future, we can further study the differences between accounts reported to be domestic and foreign.
####     1. Do accounts reported to be domestic have higher user interaction?
####     2. Do they target US issues? What languages do they use? 
####     3. Do they post according to US time zone? 

####   From the frequency analysis, we notice significant difference in the tweeting time accross countries
####   In the future, we want to know
####     1. Do tweets posted in a particular time have higher user interaction?
####     2. Can we differentiate tweets targeting their regional issues from those targeting US issues from the post time?
